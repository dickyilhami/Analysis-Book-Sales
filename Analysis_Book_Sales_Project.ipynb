# %% [markdown]
# <a href="https://colab.research.google.com/github/dickyilhami/Analysis-Book-Sales/blob/main/Analysis_Book_Sales_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORT DATASET

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
#!pip install openpyxl --upgrade

# %%
import re
from google.colab import files

# %%
df1 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/Data-penjualan-reseller-Shopee.xlsx?raw=true")

# %%
df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true")

# %%
df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true")

# %% [markdown]
# #LIST PROVINSI INDONESIA

# %%
df_prov = pd.read_csv('https://raw.githubusercontent.com/edwardsamuel/Wilayah-Administratif-Indonesia/master/csv/provinces.csv', delimiter=',', header=None)
df_prov
# Out:
#      0                          1
# 0   11                       ACEH
# 1   12             SUMATERA UTARA
# 2   13             SUMATERA BARAT
# 3   14                       RIAU
# 4   15                      JAMBI
# 5   16           SUMATERA SELATAN
# 6   17                   BENGKULU
# 7   18                    LAMPUNG
# 8   19  KEPULAUAN BANGKA BELITUNG
# 9   21             KEPULAUAN RIAU
# 10  31                DKI JAKARTA
# 11  32                 JAWA BARAT
# 12  33                JAWA TENGAH
# 13  34              DI YOGYAKARTA
# 14  35                 JAWA TIMUR
# 15  36                     BANTEN
# 16  51                       BALI
# 17  52        NUSA TENGGARA BARAT
# 18  53        NUSA TENGGARA TIMUR
# 19  61           KALIMANTAN BARAT
# 20  62          KALIMANTAN TENGAH
# 21  63         KALIMANTAN SELATAN
# 22  64           KALIMANTAN TIMUR
# 23  65           KALIMANTAN UTARA
# 24  71             SULAWESI UTARA
# 25  72            SULAWESI TENGAH
# ...

# %%
df_prov.rename(columns={0: 'Kode',1: 'Provinsi'}, inplace=True)

# %%
df_prov
# Out:
#     Kode                   Provinsi
# 0     11                       ACEH
# 1     12             SUMATERA UTARA
# 2     13             SUMATERA BARAT
# 3     14                       RIAU
# 4     15                      JAMBI
# 5     16           SUMATERA SELATAN
# 6     17                   BENGKULU
# 7     18                    LAMPUNG
# 8     19  KEPULAUAN BANGKA BELITUNG
# 9     21             KEPULAUAN RIAU
# 10    31                DKI JAKARTA
# 11    32                 JAWA BARAT
# 12    33                JAWA TENGAH
# 13    34              DI YOGYAKARTA
# 14    35                 JAWA TIMUR
# 15    36                     BANTEN
# 16    51                       BALI
# 17    52        NUSA TENGGARA BARAT
# 18    53        NUSA TENGGARA TIMUR
# 19    61           KALIMANTAN BARAT
# 20    62          KALIMANTAN TENGAH
# 21    63         KALIMANTAN SELATAN
# 22    64           KALIMANTAN TIMUR
# 23    65           KALIMANTAN UTARA
# 24    71             SULAWESI UTARA
# ...

# %% [markdown]
# #LIST KABUPATEN/KOTA INDONESIA

# %%
df_kab = pd.read_csv('https://raw.githubusercontent.com/edwardsamuel/Wilayah-Administratif-Indonesia/master/csv/regencies.csv', delimiter=',', header=None)
df_kab
# Out:
#         0   1                        2
# 0    1101  11       KABUPATEN SIMEULUE
# 1    1102  11   KABUPATEN ACEH SINGKIL
# 2    1103  11   KABUPATEN ACEH SELATAN
# 3    1104  11  KABUPATEN ACEH TENGGARA
# 4    1105  11     KABUPATEN ACEH TIMUR
# ..    ...  ..                      ...
# 509  9433  94         KABUPATEN PUNCAK
# 510  9434  94        KABUPATEN DOGIYAI
# 511  9435  94     KABUPATEN INTAN JAYA
# 512  9436  94         KABUPATEN DEIYAI
# 513  9471  94            KOTA JAYAPURA
#
# [514 rows x 3 columns]

# %%
df_kab.rename(columns={0: 'a', 1: 'Kode',2: 'Kabupaten/Kota'}, inplace=True)

# %%
df_kab
# Out:
#         a  Kode           Kabupaten/Kota
# 0    1101    11       KABUPATEN SIMEULUE
# 1    1102    11   KABUPATEN ACEH SINGKIL
# 2    1103    11   KABUPATEN ACEH SELATAN
# 3    1104    11  KABUPATEN ACEH TENGGARA
# 4    1105    11     KABUPATEN ACEH TIMUR
# ..    ...   ...                      ...
# 509  9433    94         KABUPATEN PUNCAK
# 510  9434    94        KABUPATEN DOGIYAI
# 511  9435    94     KABUPATEN INTAN JAYA
# 512  9436    94         KABUPATEN DEIYAI
# 513  9471    94            KOTA JAYAPURA
#
# [514 rows x 3 columns]

# %%
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace('KABUPATEN ', '')
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace('KOTA ', '')

# %%
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("BARU", "KOTABARU")
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("PEKANKOTABARU", "PEKANBARU")
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("BANJAR KOTABARU", "BANJAR BARU")
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("KEPULAUAN TALAUD", "TALAUD")
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("LUBUKLINGGAU", "LUBUK LINGGAU")
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("KARANG ASEM", "KARANGASEM")
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("PANGKAL PINANG", "PANGKALPINANG")
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("B A T A M", "BATAM")
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("S I A K", "SIAK")
df_kab['Kabupaten/Kota'] = df_kab['Kabupaten/Kota'].str.replace("D U M A I", "DUMAI")

# %%
df_kab
# Out:
#         a  Kode Kabupaten/Kota
# 0    1101    11       SIMEULUE
# 1    1102    11   ACEH SINGKIL
# 2    1103    11   ACEH SELATAN
# 3    1104    11  ACEH TENGGARA
# 4    1105    11     ACEH TIMUR
# ..    ...   ...            ...
# 509  9433    94         PUNCAK
# 510  9434    94        DOGIYAI
# 511  9435    94     INTAN JAYA
# 512  9436    94         DEIYAI
# 513  9471    94       JAYAPURA
#
# [514 rows x 3 columns]

# %%
df_kab.sort_values(by=['Kabupaten/Kota'], key=lambda x:x.str.len(), ascending=[False])
# Out:
#         a  Kode              Kabupaten/Kota
# 109  1612    16  PENUKAL ABAB LEMATANG ILIR
# 105  1608    16   OGAN KOMERING ULU SELATAN
# 379  7110    71   BOLAANG MONGONDOW SELATAN
# 406  7309    73    PANGKAJENE DAN KEPULAUAN
# 376  7107    71     BOLAANG MONGONDOW UTARA
# ..    ...   ...                         ...
# 33   1211    12                        KARO
# 388  7204    72                        POSO
# 204  3318    33                        PATI
# 391  7207    72                        BUOL
# 414  7317    73                        LUWU
#
# [514 rows x 3 columns]

# %%
list_kab = df_kab['Kabupaten/Kota'].to_list()

# %%
list_kab
# Out:
# ['SIMEULUE',
#  'ACEH SINGKIL',
#  'ACEH SELATAN',
#  'ACEH TENGGARA',
#  'ACEH TIMUR',
#  'ACEH TENGAH',
#  'ACEH BARAT',
#  'ACEH BESAR',
#  'PIDIE',
#  'BIREUEN',
#  'ACEH UTARA',
#  'ACEH BARAT DAYA',
#  'GAYO LUES',
#  'ACEH TAMIANG',
#  'NAGAN RAYA',
#  'ACEH JAYA',
#  'BENER MERIAH',
#  'PIDIE JAYA',
#  'BANDA ACEH',
#  'SABANG',
#  'LANGSA',
#  'LHOKSEUMAWE',
#  'SUBULUSSALAM',
#  'NIAS',
#  'MANDAILING NATAL',
#  'TAPANULI SELATAN',
#  'TAPANULI TENGAH',
#  'TAPANULI UTARA',
#  'TOBA SAMOSIR',
#  'LABUHAN BATU',
#  'ASAHAN',
#  'SIMALUNGUN',
#  'DAIRI',
#  'KARO',
#  'DELI SERDANG',
#  'LANGKAT',
#  'NIAS SELATAN',
#  'HUMBANG HASUNDUTAN',
#  'PAKPAK BHARAT',
#  'SAMOSIR',
#  'SERDANG BEDAGAI',
#  'BATU BARA',
#  'PADANG LAWAS UTARA',
#  'PADANG LAWAS',
#  'LABUHAN BATU SELATAN',
#  'LABUHAN BATU UTARA',
#  'NIAS UTARA',
#  'NIAS BARAT',
#  'SIBOLGA',
#  'TANJUNG BALAI',
#  'PEMATANG SIANTAR',
#  'TEBING TINGGI',
#  'MEDAN',
#  'BINJAI',
#  'PADANGSIDIMPUAN',
# ...

# %%
list_kab = ['PENUKAL ABAB LEMATANG ILIR',
 'BOLAANG MONGONDOW SELATAN',
 'OGAN KOMERING ULU SELATAN',
 'PANGKAJENE DAN KEPULAUAN',
 'BOLAANG MONGONDOW TIMUR',
 'OGAN KOMERING ULU TIMUR',
 'BOLAANG MONGONDOW UTARA',
 'SIAU TAGULANDANG BIARO',
 'MALUKU TENGGARA BARAT',
 'TANJUNG JABUNG BARAT',
 'TANJUNG JABUNG TIMUR',
 'LABUHAN BATU SELATAN',
 'TIMOR TENGAH SELATAN',
 'TULANG BAWANG BARAT',
 'PENAJAM PASER UTARA',
 'HULU SUNGAI SELATAN',
 'PEGUNUNGAN BINTANG',
 'TIMOR TENGAH UTARA',
 'HULU SUNGAI TENGAH',
 'SERAM BAGIAN BARAT',
 'KOTAWARINGIN TIMUR',
 'KOTAWARINGIN BARAT',
 'PADANG LAWAS UTARA',
 'OGAN KOMERING ILIR',
 'SERAM BAGIAN TIMUR',
 'LABUHAN BATU UTARA',
 'HUMBANG HASUNDUTAN',
 'KEPULAUAN MENTAWAI',
 'KEPULAUAN ANAMBAS',
 'HULU SUNGAI UTARA',
 'HALMAHERA SELATAN',
 'KUTAI KARTANEGARA',
 'MANOKWARI SELATAN',
 'BOLAANG MONGONDOW',
 'KEPULAUAN SANGIHE',
 'BANGGAI KEPULAUAN',
 'TANGERANG SELATAN',
 'KEPULAUAN MERANTI',
 'KEPULAUAN SELAYAR',
 'SIDENRENG RAPPANG',
 'MALUKU BARAT DAYA',
 'OGAN KOMERING ULU',
 'MINAHASA TENGGARA',
 'SUMBA BARAT DAYA',
 'TAPANULI SELATAN',
 'MINAHASA SELATAN',
 'MANDAILING NATAL',
 'TIDORE KEPULAUAN',
 'MAMBERAMO TENGAH',
 'BENGKULU SELATAN',
 'MUSI RAWAS UTARA',
 'HALMAHERA TENGAH',
 'KONAWE KEPULAUAN',
 'KEPULAUAN SERIBU',
 'KUANTAN SINGINGI',
 'PEMATANG SIANTAR',
 'PEGUNUNGAN ARFAK',
 'TAPANULI TENGAH',
 'KEPULAUAN YAPEN',
 'SERDANG BEDAGAI',
 'PADANGSIDIMPUAN',
 'PESISIR SELATAN',
 'HALMAHERA TIMUR',
 'PADANG PARIAMAN',
 'LIMA PULUH KOTA',
 'ACEH BARAT DAYA',
 'JAKARTA SELATAN',
 'GORONTALO UTARA',
 'HALMAHERA BARAT',
 'HALMAHERA UTARA',
 'MALUKU TENGGARA',
 'MANGGARAI BARAT',
 'INDRAGIRI HILIR',
 'MANGGARAI TIMUR',
 'BENGKULU TENGAH',
 'LAMPUNG SELATAN',
 'POLEWALI MANDAR',
 'BELITUNG TIMUR',
 'PADANG PANJANG',
 'SORONG SELATAN',
 'MAMBERAMO RAYA',
 'INDRAGIRI HULU',
 'TAPANULI UTARA',
 'TANJUNG PINANG',
 'BANGKA SELATAN',
 'LAMPUNG TENGAH',
 'BANDAR LAMPUNG',
 'KONAWE SELATAN',
 'BENGKULU UTARA',
 'BARITO SELATAN',
 'PANGKALPINANG',
 'PARIGI MOUTONG',
 'MUSI BANYUASIN',
 'KEPULAUAN SULA',
 'MINAHASA UTARA',
 'MOROWALI UTARA',
 'REJANG LEBONG',
 'BANGKA TENGAH',
 'PASAMAN BARAT',
 'SOLOK SELATAN',
 'TELUK BINTUNI',
 'MAMUJU TENGAH',
 'PULAU MOROTAI',
 'PALANGKA RAYA',
 'PULAU TALIABU',
 'ACEH TENGGARA',
 'MALUKU TENGAH',
 'PAKPAK BHARAT',
 'SUMBAWA BARAT',
 'JAKARTA TIMUR',
 'JAKARTA UTARA',
 'KEPULAUAN ARU',
 'TEBING TINGGI',
 'JAKARTA PUSAT',
 'PESISIR BARAT',
 'LOMBOK TENGAH',
 'TANJUNG BALAI',
 'LAMPUNG BARAT',
 'BUTON SELATAN',
 'BANDUNG BARAT',
 'LAMPUNG TIMUR',
 'LAMPUNG UTARA',
 'TELUK WONDAMA',
 'JAKARTA BARAT',
 'KAYONG UTARA',
 'FLORES TIMUR',
 'BARITO UTARA',
 'BANJARNEGARA',
 'KOLAKA TIMUR',
 'MAMUJU UTARA',
 'TOBA SAMOSIR',
 'TULANGBAWANG',
 'EMPAT LAWANG',
 'LUBUK LINGGAU',
 'SUNGAI PENUH',
 'ACEH TAMIANG',
 'LOMBOK BARAT',
 'PADANG LAWAS',
 'LOMBOK TIMUR',
 'BANGKA BARAT',
 'LOMBOK UTARA',
 'BURU SELATAN',
 'BENER MERIAH',
 'PULANG PISAU',
 'BARITO KUALA',
 'TORAJA UTARA',
 'BONE BOLANGO',
 'BANGGAI LAUT',
 'ACEH SINGKIL',
 'BOVEN DIGOEL',
 'GUNUNG KIDUL',
 'MAHAKAM HULU',
 'DELI SERDANG',
 'ACEH SELATAN',
 'LABUHAN BATU',
 'GUNUNGSITOLI',
 'BUTON TENGAH',
 'SUBULUSSALAM',
 'KONAWE UTARA',
 'KOLAKA UTARA',
 'BARITO TIMUR',
 'NIAS SELATAN',
 'SUMBA TENGAH',
 'TOJO UNA-UNA',
 'TASIKMALAYA',
 'BATANG HARI',
 'MUARO JAMBI',
 'LHOKSEUMAWE',
 'KARANGANYAR',
 'KARANGASEM',
 'BUKITTINGGI',
 'SIJUNJUNG',
 'SAWAH LUNTO',
 'TASIKMALAYA',
 'SUMBA TIMUR',
 'PANGANDARAN',
 'BANJARMASIN',
 'BUTON UTARA',
 'DHARMASRAYA',
 'SUMBA BARAT',
 'TANAH BUMBU',
 'KAPUAS HULU',
 'BANJAR BARU',
 'KULON PROGO',
 'TANAH DATAR',
 'PROBOLINGGO',
 'ROKAN HILIR',
 'PROBOLINGGO',
 'BIAK NUMFOR',
 'PUNCAK JAYA',
 'PURBALINGGA',
 'ACEH TENGAH',
 'SABU RAIJUA',
 'TANA TORAJA',
 'TANA TIDUNG',
 'MURUNG RAYA',
 'TULUNGAGUNG',
 'KUTAI TIMUR',
 'KUTAI BARAT',
 'LANNY JAYA',
 'INTAN JAYA',
 'PAYAKUMBUH',
 'PANDEGLANG',
 'ROKAN HULU',
 'NIAS BARAT',
 'BENGKAYANG',
 'PAGAR ALAM',
 'BOJONEGORO',
 'ACEH BARAT',
 'TEMANGGUNG',
 'ACEH UTARA',
 'ACEH TIMUR',
 'GUNUNG MAS',
 'KOTAMOBAGU',
 'ACEH BESAR',
 'PEKALONGAN',
 'NAGAN RAYA',
 'LUWU UTARA',
 'LUWU TIMUR',
 'TRENGGALEK',
 'PRABUMULIH',
 'MUARA ENIM',
 'PURWAKARTA',
 'PEKALONGAN',
 'MAJALENGKA',
 'MUNA BARAT',
 'MUSI RAWAS',
 'NIAS UTARA',
 'BALIKPAPAN',
 'SLEMAN',
 'BANTUL',
 'YOGYAKARTA',
 'BANYU ASIN',
 'PIDIE JAYA',
 'JAYAWIJAYA',
 'BANYUWANGI',
 'TANAH LAUT',
 'RAJA AMPAT',
 'SAROLANGUN',
 'BANDA ACEH',
 'SINGKAWANG',
 'SIMALUNGUN',
 'MANOKWARI',
 'BULUKUMBA',
 'BENGKALIS',
 'JENEPONTO',
 'PURWOREJO',
 'PELALAWAN',
 'GAYO LUES',
 'ACEH JAYA',
 'SAMARINDA',
 'MOJOKERTO',
 'SITUBONDO',
 'BONDOWOSO',
 'KEPAHIANG',
 'SURAKARTA',
 'BATU BARA',
 'TOLI-TOLI',
 'SUKOHARJO',
 'PEKANBARU',
 'OGAN ILIR',
 'POHUWATO',
 'GORONTALO',
 'MOJOKERTO',
 'PALEMBANG',
 'BANGKALAN',
 'KLUNGKUNG',
 'TANGERANG',
 'TANGERANG',
 'PAMEKASAN',
 'KUBU RAYA',
 'ROTE NDAO',
 'PONTIANAK',
 'INDRAMAYU',
 'TANGGAMUS',
 'WAY KANAN',
 'PESAWARAN',
 'PRINGSEWU',
 'GORONTALO',
 'MANGGARAI',
 'KARAWANG',
 'KUNINGAN',
 'PONOROGO',
 'LAMONGAN',
 'SUKABUMI',
 'SUMEDANG',
 'MAGELANG',
 'PASURUAN',
 'SEMARANG',
 'SURABAYA',
 'SUKABUMI',
 'LUMAJANG',
 'PARIAMAN',
 'GROBOGAN',
 'BENGKULU',
 'BADUNG',
 'BANJAR',
 'MAKASSAR',
 'BANGKA',
 'BELITUNG',
 'SIDOARJO',
 'MUKOMUKO',
 'BANYUMAS',
 'MAGELANG',
 'BOYOLALI',
 'WONOGIRI',
 'SEMARANG',
 'WONOSOBO',
 'DENPASAR',
 'MERANGIN',
 'PEMALANG',
 'SALATIGA',
 'JEMBRANA',
 'DONGGALA',
 'TAMBRAUW',
 'BULELENG',
 'YAHUKIMO',
 'JAYAPURA',
 'TOLIKARA',
 'TABALONG',
 'KETAPANG',
 'LAMANDAU',
 'KOTABARU',
 'BULUNGAN',
 'MINAHASA',
 'MOROWALI',
 'MEMPAWAH',
 'KATINGAN',
 'WAKATOBI',
 'SUKAMARA',
 'JAYAPURA',
 'SIMEULUE',
 'BALANGAN',
 'PASURUAN',
 'PAREPARE',
 'ENREKANG',
 'BANTAENG',
 'NAGEKEO',
 'SERUYAN',
 'KERINCI',
 'SEKADAU',
 'TERNATE',
 'CILEGON',
 'MATARAM',
 'BIREUEN',
 'SUMBAWA',
 'SUMENEP',
 'SANGGAU',
 'DOGIYAI',
 'WAROPEN',
 'JOMBANG',
 'NGANJUK',
 'LEMBATA',
 'BOALEMO',
 'MAGETAN',
 'SUPIORI',
 'BANDUNG',
 'CIANJUR',
 'SAMPANG',
 'GIANYAR',
 'TABANAN',
 'SINTANG',
 'KEBUMEN',
 'KARIMUN',
 'CILACAP',
 'KAIMANA',
 'NUNUKAN',
 'CIREBON',
 'BONTANG',
 'PINRANG',
 'SOPPENG',
 'TAKALAR',
 'PACITAN',
 'REMBANG',
 'TARAKAN',
 'LANGKAT',
 'MALINAU',
 'MAYBRAT',
 'PASAMAN',
 'MERAUKE',
 'BOMBANA',
 'CIREBON',
 'SAMOSIR',
 'TOMOHON',
 'KENDARI',
 'BANDUNG',
 'SIBOLGA',
 'BANGGAI',
 'MIMIKA',
 'MALAKA',
 'JEMBER',
 'KEEROM',
 'DEIYAI',
 'KUPANG',
 'PUNCAK',
 'YALIMO',
 'LANDAK',
 'KUPANG',
 'SAMBAS',
 'MELAWI',
 'BANGLI',
 'MALANG',
 'KAPUAS',
 'LEBAK',
 'BITUNG',
 'ASAHAN',
 'JEPARA',
 'BREBES',
 'SABANG',
 'SINJAI',
 'BLITAR',
 'TALAUD',
 'PANIAI',
 'SRAGEN',
 'KLATEN',
 'PATI',
 'BATANG',
 'KENDAL',
 'MANADO',
 'KEDIRI',
 'NABIRE',
 'SERANG',
 'LEBONG',
 'MADIUN',
 'LINGGA',
 'BEKASI',
 'MAJENE',
 'KAMPAR',
 'CIAMIS',
 'BAUBAU',
 'MAMUJU',
 'CIMAHI',
 'SELUMA',
 'FAKFAK',
 'MESUJI',
 'SUBANG',
 'MALANG',
 'MAMASA',
 'BEKASI',
 'KOLAKA',
 'BLITAR',
 'KEDIRI',
 'KONAWE',
 'GRESIK',
 'BANJAR',
 'LANGSA',
 'SERANG',
 'BINJAI',
 'MADIUN',
 'SORONG',
 'BINTAN',
 'PALOPO',
 'PADANG',
 'SORONG',
 'NATUNA',
 'PASER',
 'BOGOR',
 'BERAU',
 'TEGAL',
 'TEGAL',
 'DEMAK',
 'KUDUS',
 'BLORA',
 'BARRU',
 'BUTON',
 'AMBON',
 'METRO',
 'BATAM',
 'BOGOR',
 'GARUT',
 'DEPOK',
 'TUBAN',
 'NGAWI',
 'LAHAT',
 'TAPIN',
 'NDUGA',
 'PIDIE',
 'MEDAN',
 'SARMI',
 'MAPPI',
 'ASMAT',
 'BUNGO',
 'TEBO',
 'JAMBI',
 'DUMAI',
 'DAIRI',
 'SOLOK',
 'SIKKA',
 'MAROS',
 'NGADA',
 'SOLOK',
 'DOMPU',
 'PALU',
 'NIAS',
 'GOWA',
 'AGAM',
 'MUNA',
 'KARO',
 'POSO',
 'BUOL',
 'SIAK',
 'BELU',
 'SIGI',
 'BURU',
 'BONE',
 'BATU',
 'WAJO',
 'TUAL',
 'BIMA',
 'BIMA',
 'ALOR',
 'KAUR',
 'ENDE',
 'LUWU']

# %%
list_kab
# Out:
# ['PENUKAL ABAB LEMATANG ILIR',
#  'BOLAANG MONGONDOW SELATAN',
#  'OGAN KOMERING ULU SELATAN',
#  'PANGKAJENE DAN KEPULAUAN',
#  'BOLAANG MONGONDOW TIMUR',
#  'OGAN KOMERING ULU TIMUR',
#  'BOLAANG MONGONDOW UTARA',
#  'SIAU TAGULANDANG BIARO',
#  'MALUKU TENGGARA BARAT',
#  'TANJUNG JABUNG BARAT',
#  'TANJUNG JABUNG TIMUR',
#  'LABUHAN BATU SELATAN',
#  'TIMOR TENGAH SELATAN',
#  'TULANG BAWANG BARAT',
#  'PENAJAM PASER UTARA',
#  'HULU SUNGAI SELATAN',
#  'PEGUNUNGAN BINTANG',
#  'TIMOR TENGAH UTARA',
#  'HULU SUNGAI TENGAH',
#  'SERAM BAGIAN BARAT',
#  'KOTAWARINGIN TIMUR',
#  'KOTAWARINGIN BARAT',
#  'PADANG LAWAS UTARA',
#  'OGAN KOMERING ILIR',
#  'SERAM BAGIAN TIMUR',
#  'LABUHAN BATU UTARA',
#  'HUMBANG HASUNDUTAN',
#  'KEPULAUAN MENTAWAI',
#  'KEPULAUAN ANAMBAS',
#  'HULU SUNGAI UTARA',
#  'HALMAHERA SELATAN',
#  'KUTAI KARTANEGARA',
#  'MANOKWARI SELATAN',
#  'BOLAANG MONGONDOW',
#  'KEPULAUAN SANGIHE',
#  'BANGGAI KEPULAUAN',
#  'TANGERANG SELATAN',
# ...

# %% [markdown]
# #TABEL KABUPATEN/KOTA DAN PROVINSI

# %%
df_kab = df_kab.merge(df_prov, on='Kode', how='left')

# %%
df_kab
# Out:
#         a  Kode Kabupaten/Kota Provinsi
# 0    1101    11       SIMEULUE     ACEH
# 1    1102    11   ACEH SINGKIL     ACEH
# 2    1103    11   ACEH SELATAN     ACEH
# 3    1104    11  ACEH TENGGARA     ACEH
# 4    1105    11     ACEH TIMUR     ACEH
# ..    ...   ...            ...      ...
# 509  9433    94         PUNCAK    PAPUA
# 510  9434    94        DOGIYAI    PAPUA
# 511  9435    94     INTAN JAYA    PAPUA
# 512  9436    94         DEIYAI    PAPUA
# 513  9471    94       JAYAPURA    PAPUA
#
# [514 rows x 4 columns]

# %%
prov_df = df_kab.loc[:,['Kabupaten/Kota', 'Provinsi']]

# %%
prov_df
# Out:
#     Kabupaten/Kota Provinsi
# 0         SIMEULUE     ACEH
# 1     ACEH SINGKIL     ACEH
# 2     ACEH SELATAN     ACEH
# 3    ACEH TENGGARA     ACEH
# 4       ACEH TIMUR     ACEH
# ..             ...      ...
# 509         PUNCAK    PAPUA
# 510        DOGIYAI    PAPUA
# 511     INTAN JAYA    PAPUA
# 512         DEIYAI    PAPUA
# 513       JAYAPURA    PAPUA
#
# [514 rows x 2 columns]

# %%
x = {'Kabupaten/Kota':'UNDEFINED', 'Provinsi':'UNDEFINED'}

# %%
prov_df = prov_df.append(x, ignore_index=True)
prov_df
# Out:
#     Kabupaten/Kota   Provinsi
# 0         SIMEULUE       ACEH
# 1     ACEH SINGKIL       ACEH
# 2     ACEH SELATAN       ACEH
# 3    ACEH TENGGARA       ACEH
# 4       ACEH TIMUR       ACEH
# ..             ...        ...
# 510        DOGIYAI      PAPUA
# 511     INTAN JAYA      PAPUA
# 512         DEIYAI      PAPUA
# 513       JAYAPURA      PAPUA
# 514      UNDEFINED  UNDEFINED
#
# [515 rows x 2 columns]

# %% [markdown]
# #DATASET 1 : RESELLER SHOPEE

# %% [markdown]
# ## Check Dataset 1

# %%
df1
# Out:
#               Tgl Order                                        judul buku   \
# 0      2020-10-25 18:48                Konstruksi Bangunan - BUKU ORIGINAL
# 1      2020-10-25 18:49  Kiat Sukses Meraih Hibah Penelitian Pengembang...
# 2      2020-12-01 07:46  PROMO Buku Pembelajaran Inkuiri di Masa Pandem...
# 3      2020-12-01 09:58  Semiotika Dokumenter:Membongkar Dekonstruksi M...
# 4      2020-12-01 11:00       Buku Kepastian Hukum Gadai Tanah dalam Islam
# ...                 ...                                                ...
# 10928  2021-12-15 11:30  Buku Pemetaan Sosial Analisis Jaringan Struktu...
# 10929  2021-12-15 12:16  Buku The Soft Power Of South Korea - BUKU ASLI...
# 10930  2021-12-15 12:39  Buku The Power of Gratitude Kekuatan Syukur da...
# 10931  2021-12-15 16:16  Buku Motivasi Belajar Dalam Perkembangan Remaj...
# 10932  2021-12-15 20:06  PROMO Buku Analisa dan Perancangan Sistem Info...
#
#        Harga Awal  jumlah pesanan  Total Berat  Total Pembayaran  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10933 entries, 0 to 10932
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tgl Order               10933 non-null  object
#  1   judul buku              10933 non-null  object
#  2   Harga Awal              10593 non-null  float64
#  3   jumlah pesanan          10933 non-null  int64
#  4   Total Berat             10933 non-null  object
#  5   Total Pembayaran        10933 non-null  int64
#  6   Perkiraan Ongkos Kirim  10933 non-null  int64
#  7   Alamat                  10487 non-null  object
#  8   Kota/Kabupaten          10926 non-null  object
#  9   Provinsi                10926 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 854.3+ KB

# %% [markdown]
# ##Memperbaiki format dari fitur-fitur yang ada pada Dataset 1

# %%
df1.columns
# Out:
# Index(['Tgl Order', 'judul buku ', 'Harga Awal', 'jumlah pesanan ',
#        'Total Berat', 'Total Pembayaran', 'Perkiraan Ongkos Kirim', 'Alamat ',
#        'Kota/Kabupaten', 'Provinsi'],
#       dtype='object')

# %%
df1.rename(columns={'Alamat ': 'Alamat','judul buku ': 'Judul Buku','jumlah pesanan ':'Jumlah Pesanan', 'Provinsi':'Provinsi_raw'}, inplace=True)

# %%
df1['Tgl Order'] = pd.to_datetime(df1['Tgl Order'])

# %%
df1['Alamat']=df1['Alamat'].apply(str)

# %%
df1['Alamat'] = df1['Alamat'].str.upper()
alamat_df = df1['Alamat']
alamat_df
# Out:
# 0                                                 WI******
# 1                                                 JL******
# 2                                                 DU******
# 3        JL. KH. HARUN NAFSI PERUMAHAN GEMILANG 1 BLOK ...
# 4                                                 DE******
#                                ...
# 10928                                                  NAN
# 10929    RT.3/RW.14, BONJOTAN, NGAGLIK. KOST GRIYA TENT...
# 10930    DUSUN CENDIL RT 11 RW 03 DESA ALASTENGAH, KAB....
# 10931    TIDENG PALE TIMUR, JALAN MANUNGGAL, RT.4/RW.1,...
# 10932    KOMPLEK PURI BASTARI ABADI C14, MASUK LORONG S...
# Name: Alamat, Length: 10933, dtype: object

# %%
df1['Judul Buku'] = df1['Judul Buku'].str.title()
df1['Judul Buku']
# Out:
# 0                      Konstruksi Bangunan - Buku Original
# 1        Kiat Sukses Meraih Hibah Penelitian Pengembang...
# 2        Promo Buku Pembelajaran Inkuiri Di Masa Pandem...
# 3        Semiotika Dokumenter:Membongkar Dekonstruksi M...
# 4             Buku Kepastian Hukum Gadai Tanah Dalam Islam
#                                ...
# 10928    Buku Pemetaan Sosial Analisis Jaringan Struktu...
# 10929    Buku The Soft Power Of South Korea - Buku Asli...
# 10930    Buku The Power Of Gratitude Kekuatan Syukur Da...
# 10931    Buku Motivasi Belajar Dalam Perkembangan Remaj...
# 10932    Promo Buku Analisa Dan Perancangan Sistem Info...
# Name: Judul Buku, Length: 10933, dtype: object

# %%
df1['Kota/Kabupaten']=df1['Kota/Kabupaten'].apply(str)

# %%
df1['Kota/Kabupaten'] = df1['Kota/Kabupaten'].str.upper()

# %%
df1['Kota/Kabupaten'] = df1['Kota/Kabupaten'].str.replace('KAB. ', '')
df1['Kota/Kabupaten'] = df1['Kota/Kabupaten'].str.replace('KOTA ', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df1['Total Pembayaran'] = df1['Total Pembayaran'].astype(float)

# %%
#kab_df = df1['Kota/Kabupaten']
#kab_df

# %% [markdown]
# ##Melakukan pengecekan Nama Kabupaten/Kota yang terdapat pada Alamat dan memisahkannya menjadi kolom baru pada Dataset 1

# %%
#def Kab(alamat, kab_raw):
#  kabupaten = ""
#  if re.search('KABUPATEN',alamat):
#    tmp = re.search('KABUPATEN',alamat)
#    data_to_find = alamat[tmp.end()::]
#  elif re.search('KOTA',alamat):
#    tmp = re.search('KOTA',alamat)
#    data_to_find = alamat[tmp.end()::]
#  else:
#   data_to_find = alamat
#
#  for kab in list_kab:
#    if kab in data_to_find:
#      kabupaten = kab
#      break
#  if (kabupaten == ''):
#    kabupaten = kab_raw
  
#  return kabupaten

# %%
#data_alamat = [Kab(alamat,kab_raw) for alamat in alamat_df.to_list() for kab_raw in kab_df.to_list()]

# %%
#data_alamat

# %%
def kab(alamat, kab_raw):
  kabupaten=''
  alamat_list = alamat.to_list()
  kab_raw_list = kab_raw.to_list()
  ls_kab = list()
  for i in range(len(alamat_list)):
    for j in list_kab:
      if (str(j) in str(alamat_list[i])):
        #print(j)
        #print(i)
        kabupaten = j
        break
      else:
        # jika tidak ada dalam list, maka ambil kolom kabupaten/kota
        kabupaten = str(kab_raw[i])
    ls_kab.append(kabupaten)
  
  #print(ls_kab)
  return ls_kab

# %%
def kab(alamat, kab_raw):
  kabupaten=''
  alamat_list = alamat.to_list()
  kab_raw_list = kab_raw.to_list()
  ls_kab = list()
  for i in range(len(alamat_list)):
    for j in list_kab:
      if (str(j) in str(alamat_list[i])):
        kabupaten = j
        break
      else:
        # jika tidak ada dalam list, maka ambil kolom kabupaten/kota
        kabupaten = str(kab_raw[i])
    ls_kab.append(kabupaten)
  
  #print(ls_kab)
  return ls_kab

# %%
ls = list()
ls = kab(df1['Alamat'], df1['Kota/Kabupaten'])

# %%
df1['Kabupaten/Kota'] = ls

# %%
df1
# Out:
#                 Tgl Order                                         Judul Buku  \
# 0     2020-10-25 18:48:00                Konstruksi Bangunan - Buku Original
# 1     2020-10-25 18:49:00  Kiat Sukses Meraih Hibah Penelitian Pengembang...
# 2     2020-12-01 07:46:00  Promo Buku Pembelajaran Inkuiri Di Masa Pandem...
# 3     2020-12-01 09:58:00  Semiotika Dokumenter:Membongkar Dekonstruksi M...
# 4     2020-12-01 11:00:00       Buku Kepastian Hukum Gadai Tanah Dalam Islam
# ...                   ...                                                ...
# 10928 2021-12-15 11:30:00  Buku Pemetaan Sosial Analisis Jaringan Struktu...
# 10929 2021-12-15 12:16:00  Buku The Soft Power Of South Korea - Buku Asli...
# 10930 2021-12-15 12:39:00  Buku The Power Of Gratitude Kekuatan Syukur Da...
# 10931 2021-12-15 16:16:00  Buku Motivasi Belajar Dalam Perkembangan Remaj...
# 10932 2021-12-15 20:06:00  Promo Buku Analisa Dan Perancangan Sistem Info...
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10933 entries, 0 to 10932
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tgl Order               10933 non-null  datetime64[ns]
#  1   Judul Buku              10933 non-null  object
#  2   Harga Awal              10593 non-null  float64
#  3   Jumlah Pesanan          10933 non-null  int64
#  4   Total Berat             10933 non-null  object
#  5   Total Pembayaran        10933 non-null  float64
#  6   Perkiraan Ongkos Kirim  10933 non-null  int64
#  7   Alamat                  10933 non-null  object
#  8   Kota/Kabupaten          10933 non-null  object
#  9   Provinsi_raw            10926 non-null  object
#  10  Kabupaten/Kota          10933 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 939.7+ KB

# %% [markdown]
# ##Menambahkan Kolom Provinsi

# %%
df1 = df1.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
df1
# Out:
#                 Tgl Order                                         Judul Buku  \
# 0     2020-10-25 18:48:00                Konstruksi Bangunan - Buku Original
# 1     2020-10-25 18:49:00  Kiat Sukses Meraih Hibah Penelitian Pengembang...
# 2     2020-12-01 07:46:00  Promo Buku Pembelajaran Inkuiri Di Masa Pandem...
# 3     2020-12-01 09:58:00  Semiotika Dokumenter:Membongkar Dekonstruksi M...
# 4     2020-12-01 11:00:00       Buku Kepastian Hukum Gadai Tanah Dalam Islam
# ...                   ...                                                ...
# 13351 2021-12-15 12:16:00  Buku The Soft Power Of South Korea - Buku Asli...
# 13352 2021-12-15 12:39:00  Buku The Power Of Gratitude Kekuatan Syukur Da...
# 13353 2021-12-15 12:39:00  Buku The Power Of Gratitude Kekuatan Syukur Da...
# 13354 2021-12-15 16:16:00  Buku Motivasi Belajar Dalam Perkembangan Remaj...
# 13355 2021-12-15 20:06:00  Promo Buku Analisa Dan Perancangan Sistem Info...
#
# ...

# %%
df1.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#       Kabupaten/Kota          Provinsi
# 0          SUKOHARJO       JAWA TENGAH
# 1      JAKARTA TIMUR       DKI JAKARTA
# 2           SIDOARJO        JAWA TIMUR
# 3          SAMARINDA  KALIMANTAN TIMUR
# 4              LAHAT  SUMATERA SELATAN
# ...              ...               ...
# 13351         SLEMAN     DI YOGYAKARTA
# 13352    PROBOLINGGO        JAWA TIMUR
# 13353    PROBOLINGGO        JAWA TIMUR
# 13354    TANA TIDUNG  KALIMANTAN UTARA
# 13355      PALEMBANG  SUMATERA SELATAN
#
# [13356 rows x 2 columns]

# %% [markdown]
# ##Memisahkan Month dan Year dari Tgl Order pada Dataset 1

# %%
df1['Month'] = pd.DatetimeIndex(df1['Tgl Order']).month

# %%
df1['Year'] = pd.DatetimeIndex(df1['Tgl Order']).year

# %%
df1
# Out:
#                 Tgl Order                                         Judul Buku  \
# 0     2020-10-25 18:48:00                Konstruksi Bangunan - Buku Original
# 1     2020-10-25 18:49:00  Kiat Sukses Meraih Hibah Penelitian Pengembang...
# 2     2020-12-01 07:46:00  Promo Buku Pembelajaran Inkuiri Di Masa Pandem...
# 3     2020-12-01 09:58:00  Semiotika Dokumenter:Membongkar Dekonstruksi M...
# 4     2020-12-01 11:00:00       Buku Kepastian Hukum Gadai Tanah Dalam Islam
# ...                   ...                                                ...
# 13351 2021-12-15 12:16:00  Buku The Soft Power Of South Korea - Buku Asli...
# 13352 2021-12-15 12:39:00  Buku The Power Of Gratitude Kekuatan Syukur Da...
# 13353 2021-12-15 12:39:00  Buku The Power Of Gratitude Kekuatan Syukur Da...
# 13354 2021-12-15 16:16:00  Buku Motivasi Belajar Dalam Perkembangan Remaj...
# 13355 2021-12-15 20:06:00  Promo Buku Analisa Dan Perancangan Sistem Info...
#
# ...

# %% [markdown]
# ##Melakukan Check Duplicated Value pada Dataset 1

# %% [markdown]
# ##Memisahkan Fitur-Fitur yang diperlukan untuk Analisa kedalam sebuah DataFrame Baru pada Dataset 1

# %%
df11 = df1.loc[:,['Year', 'Month', 'Kabupaten/Kota', 'Provinsi','Judul Buku','Jumlah Pesanan','Total Pembayaran']]
df11
# Out:
#        Year  Month Kabupaten/Kota          Provinsi  \
# 0      2020     10      SUKOHARJO       JAWA TENGAH
# 1      2020     10  JAKARTA TIMUR       DKI JAKARTA
# 2      2020     12       SIDOARJO        JAWA TIMUR
# 3      2020     12      SAMARINDA  KALIMANTAN TIMUR
# 4      2020     12          LAHAT  SUMATERA SELATAN
# ...     ...    ...            ...               ...
# 13351  2021     12         SLEMAN     DI YOGYAKARTA
# 13352  2021     12    PROBOLINGGO        JAWA TIMUR
# 13353  2021     12    PROBOLINGGO        JAWA TIMUR
# 13354  2021     12    TANA TIDUNG  KALIMANTAN UTARA
# 13355  2021     12      PALEMBANG  SUMATERA SELATAN
#
#                                               Judul Buku  Jumlah Pesanan  \
# 0                    Konstruksi Bangunan - Buku Original               1
# 1      Kiat Sukses Meraih Hibah Penelitian Pengembang...               1
# 2      Promo Buku Pembelajaran Inkuiri Di Masa Pandem...               1
# ...

# %%
df11.dtypes
# Out:
# Year                  int64
# Month                 int64
# Kabupaten/Kota       object
# Provinsi             object
# Judul Buku           object
# Jumlah Pesanan        int64
# Total Pembayaran    float64
# dtype: object

# %% [markdown]
# #DATASET 2 : ORDER 2021

# %% [markdown]
# ##JANUARI 2021

# %% [markdown]
# ###Load Dataset

# %%
JAN_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.JANUARI")
JAN_df2
# Out:
#      Tgl Order  Pemesanan                  Nama  \
# 0   2020-12-23         wa      Milka Atika Sari
# 1   2020-12-23   langsung           nur hidayat
# 2   2020-12-23         wa          gani wiharso
# 3   2020-12-23         wa          gani wiharso
# 4   2020-12-24     shopee     Nabiladiahirianti
# ..         ...        ...                   ...
# 217 2021-01-21         wa          Ibu Asriwati
# 218 2021-01-22  tokopedia        Lufi Luthfiani
# 219 2021-01-22  bukalapak  Jerry May hasudungan
# 220 2021-01-22        web          Ari Haryanto
# 221        NaT        NaN                   NaN
#
#                                                Alamat   \
# 0    Jl. Yudistira II, Kalikuning rt. 03 rw. 09, Jo...
# 1                                           yogyakarta
# 2    Perum Aneka Elok Blok D 3 No.40 Rt.005 Rw 09 K...
# 3    Perum Aneka Elok Blok D 3 No.40 Rt.005 Rw 09 K...
# 4    Depan uptd sukonatar ada gang masuk. Lurus 100...
# ...

# %%
JAN_df2 = JAN_df2.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
JAN_df2['Alamat '] = JAN_df2['Alamat '].str.upper()
alamat_df = JAN_df2['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      JL. YUDISTIRA II, KALIKUNING RT. 03 RW. 09, JO...
# 1                                             YOGYAKARTA
# 2      PERUM ANEKA ELOK BLOK D 3 NO.40 RT.005 RW 09 K...
# 3      PERUM ANEKA ELOK BLOK D 3 NO.40 RT.005 RW 09 K...
# 4      DEPAN UPTD SUKONATAR ADA GANG MASUK. LURUS 100...
#                              ...
# 216    JLN. TRANS SULAWESI\nKOTA MARISA, KABUPATEN PO...
# 217                                                MEDAN
# 218    JL. KAPTEN YUSUF GG. BEBAS RT. 01/08 NO. 18 KP...
# 219    JALAN ISMAN NO 31 KENJERAN SURABAYA, KENJERAN,...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break
  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
JAN_df2['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JAN_df2
# Out:
#      Tgl Order  Pemesanan                  Nama  \
# 0   2020-12-23         wa      Milka Atika Sari
# 1   2020-12-23   langsung           nur hidayat
# 2   2020-12-23         wa          gani wiharso
# 3   2020-12-23         wa          gani wiharso
# 4   2020-12-24     shopee     Nabiladiahirianti
# ..         ...        ...                   ...
# 216 2021-01-21         wa       Bpk. NOOR ASIEF
# 217 2021-01-21         wa          Ibu Asriwati
# 218 2021-01-22  tokopedia        Lufi Luthfiani
# 219 2021-01-22  bukalapak  Jerry May hasudungan
# 220 2021-01-22        web          Ari Haryanto
#
#                                                Alamat   \
# 0    JL. YUDISTIRA II, KALIKUNING RT. 03 RW. 09, JO...
# 1                                           YOGYAKARTA
# 2    PERUM ANEKA ELOK BLOK D 3 NO.40 RT.005 RW 09 K...
# 3    PERUM ANEKA ELOK BLOK D 3 NO.40 RT.005 RW 09 K...
# 4    DEPAN UPTD SUKONATAR ADA GANG MASUK. LURUS 100...
# ...

# %% [markdown]
# ###Menambahkan  Kolom Provinsi

# %%
JAN_df2 = JAN_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
JAN_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota       Provinsi
# 0           KLATEN    JAWA TENGAH
# 1       YOGYAKARTA  DI YOGYAKARTA
# 2    JAKARTA TIMUR    DKI JAKARTA
# 3    JAKARTA TIMUR    DKI JAKARTA
# 4       BANYUWANGI     JAWA TIMUR
# ..             ...            ...
# 262          BOGOR     JAWA BARAT
# 263          BOGOR     JAWA BARAT
# 264       SURABAYA     JAWA TIMUR
# 265        CIREBON     JAWA BARAT
# 266        CIREBON     JAWA BARAT
#
# [267 rows x 2 columns]

# %% [markdown]
# ## FEBRUARI 2021

# %% [markdown]
# ###Load Dataset

# %%
FEB_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.FEBRUARI")
FEB_df2
# Out:
#      Tgl Order  Pemesanan               Nama  \
# 0   2021-01-25     shopee          Indriyati
# 1   2021-01-25     shopee  Yuyun Dwi Lestari
# 2   2021-01-25     shopee  Yuyun Dwi Lestari
# 3   2021-01-25  bukalapak       Hadi Shubhan
# 4   2021-01-25     lazada          khifdziat
# ..         ...        ...                ...
# 414 2021-02-24     shopee              Maria
# 415 2021-02-24         wa              Ahmad
# 416 2021-02-24         wa    ILYANANDA PUTRI
# 417        NaT        NaN                NaN
# 418        NaT        NaN                NaN
#
#                                                Alamat   \
# 0    Perum Griya Asri 2 Jln. Kalpataru 6 Blok K8 No...
# 1    Yuyun PKL/BPM Hj. Sri Mustika No.27 Dusun 01 G...
# 2    Yuyun PKL/BPM Hj. Sri Mustika No.27 Dusun 01 G...
# 3    Jl. Gayungsari III No. 32 Blok A-11 (Graha Gay...
# 4    Jl. darma bakti no 153 medono Jawa Tengah Kota...
# ..                                                 ...
# ...

# %%
FEB_df2 = FEB_df2.iloc[:-2 , :]

# %% [markdown]
# ###Memisahkan  Kabupaten/Kota dari Alamat

# %%
FEB_df2['Alamat '] = FEB_df2['Alamat '].str.upper()
alamat_df = FEB_df2['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      PERUM GRIYA ASRI 2 JLN. KALPATARU 6 BLOK K8 NO...
# 1      YUYUN PKL/BPM HJ. SRI MUSTIKA NO.27 DUSUN 01 G...
# 2      YUYUN PKL/BPM HJ. SRI MUSTIKA NO.27 DUSUN 01 G...
# 3      JL. GAYUNGSARI III NO. 32 BLOK A-11 (GRAHA GAY...
# 4      JL. DARMA BAKTI NO 153 MEDONO JAWA TENGAH KOTA...
#                              ...
# 412    JL PUTAT INDAH TIMUR 3 NO 1 . KEC SUKOMANUNGGA...
# 413    JALAN MANGLID NO.71/132 GANG SAUYUNAN RT 03 RW...
# 414    JLN.TUKAD BALIAN GANG BULE NO.18, KOTA DENPASA...
# 415    REJOWINANGUN, RT/23 RW/07 NO. 413, KOTAGEDE, Y...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
FEB_df2['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
FEB_df2
# Out:
#      Tgl Order  Pemesanan               Nama  \
# 0   2021-01-25     shopee          Indriyati
# 1   2021-01-25     shopee  Yuyun Dwi Lestari
# 2   2021-01-25     shopee  Yuyun Dwi Lestari
# 3   2021-01-25  bukalapak       Hadi Shubhan
# 4   2021-01-25     lazada          khifdziat
# ..         ...        ...                ...
# 412 2021-02-24  bukalapak     Rieska Hidajat
# 413 2021-02-24         wa      dudi rudiatna
# 414 2021-02-24     shopee              Maria
# 415 2021-02-24         wa              Ahmad
# 416 2021-02-24         wa    ILYANANDA PUTRI
#
#                                                Alamat   \
# 0    PERUM GRIYA ASRI 2 JLN. KALPATARU 6 BLOK K8 NO...
# 1    YUYUN PKL/BPM HJ. SRI MUSTIKA NO.27 DUSUN 01 G...
# 2    YUYUN PKL/BPM HJ. SRI MUSTIKA NO.27 DUSUN 01 G...
# 3    JL. GAYUNGSARI III NO. 32 BLOK A-11 (GRAHA GAY...
# 4    JL. DARMA BAKTI NO 153 MEDONO JAWA TENGAH KOTA...
# ..                                                 ...
# ...

# %% [markdown]
# ###Menambahkan  Kolom Provinsi

# %%
FEB_df2 = FEB_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
FEB_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota       Provinsi
# 0           BEKASI     JAWA BARAT
# 1           BEKASI     JAWA BARAT
# 2    LAMPUNG UTARA        LAMPUNG
# 3    LAMPUNG UTARA        LAMPUNG
# 4         SURABAYA     JAWA TIMUR
# ..             ...            ...
# 518        BANDUNG     JAWA BARAT
# 519        BANDUNG     JAWA BARAT
# 520       DENPASAR           BALI
# 521     YOGYAKARTA  DI YOGYAKARTA
# 522      PEKANBARU           RIAU
#
# [523 rows x 2 columns]

# %% [markdown]
# ## MARET 2021

# %% [markdown]
# ###Load Dataset

# %%
MAR_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.MARET")
MAR_df2
# Out:
#      Tgl Order Pemesanan                  Nama  \
# 0   2021-02-25    shopee           Rita sagita
# 1   2021-02-25    shopee        ILZA AH (Sasa)
# 2   2021-02-25    shopee         Ita Widyawati
# 3   2021-02-25    shopee          Athaya hasna
# 4   2021-02-25    shopee                Haeril
# ..         ...       ...                   ...
# 340 2021-03-23        wa  arvianto Eko nugroho
# 341 2021-03-23    shopee       Milenia Safitri
# 342 2021-03-23    shopee       Milenia Safitri
# 343 2021-03-23        wa           Ulwa Gandes
# 344        NaT       NaN                   NaN
#
#                                                Alamat   \
# 0    Jalan malaka lorong mekar 3 No.1424, KOTA PALE...
# 1    Perumahan Safira Residence Blok D No.18-20 Jln...
# 2    Jalan Kunir no 45, RT 03 RW 11, Pajang, Laweya...
# 3    Jl pramuka no 16, Sadamalun, RT 003/RW 021. ( ...
# 4    Dijln H. Agussalim no 29 raha kecamatan katobu...
# ..                                                 ...
# ...

# %%
MAR_df2 = MAR_df2.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
MAR_df2['Alamat '] = MAR_df2['Alamat '].str.upper()
alamat_df = MAR_df2['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      JALAN MALAKA LORONG MEKAR 3 NO.1424, KOTA PALE...
# 1      PERUMAHAN SAFIRA RESIDENCE BLOK D NO.18-20 JLN...
# 2      JALAN KUNIR NO 45, RT 03 RW 11, PAJANG, LAWEYA...
# 3      JL PRAMUKA NO 16, SADAMALUN, RT 003/RW 021. ( ...
# 4      DIJLN H. AGUSSALIM NO 29 RAHA KECAMATAN KATOBU...
#                              ...
# 339    GRAND DEPOK CITY SEKTOR MELATI BLOK B1/7\n  KE...
# 340    JL. PUSPIPTEK RAYA, KOMPLEK PURI SERPONG 1, BL...
# 341    JL.TUTUL NO.10 RT 12 RW 04 PAPRINGAN CATURTUNG...
# 342    JL.TUTUL NO.10 RT 12 RW 04 PAPRINGAN CATURTUNG...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
MAR_df2['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
MAR_df2
# Out:
#      Tgl Order Pemesanan                  Nama  \
# 0   2021-02-25    shopee           Rita sagita
# 1   2021-02-25    shopee        ILZA AH (Sasa)
# 2   2021-02-25    shopee         Ita Widyawati
# 3   2021-02-25    shopee          Athaya hasna
# 4   2021-02-25    shopee                Haeril
# ..         ...       ...                   ...
# 339 2021-03-23        wa                 Idham
# 340 2021-03-23        wa  arvianto Eko nugroho
# 341 2021-03-23    shopee       Milenia Safitri
# 342 2021-03-23    shopee       Milenia Safitri
# 343 2021-03-23        wa           Ulwa Gandes
#
#                                                Alamat   \
# 0    JALAN MALAKA LORONG MEKAR 3 NO.1424, KOTA PALE...
# 1    PERUMAHAN SAFIRA RESIDENCE BLOK D NO.18-20 JLN...
# 2    JALAN KUNIR NO 45, RT 03 RW 11, PAJANG, LAWEYA...
# 3    JL PRAMUKA NO 16, SADAMALUN, RT 003/RW 021. ( ...
# 4    DIJLN H. AGUSSALIM NO 29 RAHA KECAMATAN KATOBU...
# ..                                                 ...
# ...

# %% [markdown]
# ###Manambkan Kolom Provinsi

# %%
MAR_df2 = MAR_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
MAR_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#         Kabupaten/Kota           Provinsi
# 0            PALEMBANG   SUMATERA SELATAN
# 1            SUKOHARJO        JAWA TENGAH
# 2            SURAKARTA        JAWA TENGAH
# 3             KARAWANG         JAWA BARAT
# 4                 MUNA  SULAWESI TENGGARA
# ..                 ...                ...
# 406              DEPOK         JAWA BARAT
# 407  TANGERANG SELATAN             BANTEN
# 408             SLEMAN      DI YOGYAKARTA
# 409             SLEMAN      DI YOGYAKARTA
# 410          SURAKARTA        JAWA TENGAH
#
# [411 rows x 2 columns]

# %% [markdown]
# ## APRIL 2021

# %% [markdown]
# ###Load Dataset

# %%
APR_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.APRIL")
APR_df2
# Out:
#      Tgl Order Pemesanan                              Nama  \
# 0   2021-03-24    shopee                            Sukran
# 1   2021-03-24    shopee               Hayatullah Kurniadi
# 2   2021-03-24       web             Rima Mardiyani Yunita
# 3   2021-03-24       web             Rima Mardiyani Yunita
# 4   2021-03-24       web                      Irwan Muslim
# ..         ...       ...                               ...
# 253 2021-04-21        wa  Rudy Harmanda ato Hj Ipin Supini
# 254 2021-04-21        wa                   Nono Prihantono
# 255 2021-04-22    shopee                       Dhiana zein
# 256 2021-04-22        wa                           ibu ana
# 257        NaT       NaN                               NaN
#
#                                                Alamat   \
# 0    Jln bogowonto RT 11 no 4a Padang harapan kelur...
# 1    Jl. Uka, garuda Sakti, Panam Perumahan Green T...
# 2    Ko. Cisereh RT/RW 02/06 Desa Kadu Jaya Kecamat...
# ...

# %%
APR_df2 = APR_df2.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
APR_df2['Alamat '] = APR_df2['Alamat '].str.upper()
alamat_df = APR_df2['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      JLN BOGOWONTO RT 11 NO 4A PADANG HARAPAN KELUR...
# 1      JL. UKA, GARUDA SAKTI, PANAM PERUMAHAN GREEN T...
# 2      KO. CISEREH RT/RW 02/06 DESA KADU JAYA KECAMAT...
# 3      KO. CISEREH RT/RW 02/06 DESA KADU JAYA KECAMAT...
# 4      PERUMAHAN SALINGKA BUNGO PERMAI 1 BLOK H/7 KEC...
#                              ...
# 252    BOGOR RAYA PERMAI FA VI NO. 6 RT 001/011 KEL. ...
# 253     DUSUN GINTUNG TENGAH NO 2 RT 019/RW 005\nDESA...
# 254    BOGOR RAYA PERMAI FA VI NO. 6 RT 001/011 KEL. ...
# 255    FIRQOH HM JL. KH MANSYUR NO.14, CEMANDI, KUNIR...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
APR_df2['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
APR_df2
# Out:
#      Tgl Order Pemesanan                              Nama  \
# 0   2021-03-24    shopee                            Sukran
# 1   2021-03-24    shopee               Hayatullah Kurniadi
# 2   2021-03-24       web             Rima Mardiyani Yunita
# 3   2021-03-24       web             Rima Mardiyani Yunita
# 4   2021-03-24       web                      Irwan Muslim
# ..         ...       ...                               ...
# 252 2021-04-21        wa                   Nono Prihantono
# 253 2021-04-21        wa  Rudy Harmanda ato Hj Ipin Supini
# 254 2021-04-21        wa                   Nono Prihantono
# 255 2021-04-22    shopee                       Dhiana zein
# 256 2021-04-22        wa                           ibu ana
#
#                                                Alamat   \
# 0    JLN BOGOWONTO RT 11 NO 4A PADANG HARAPAN KELUR...
# 1    JL. UKA, GARUDA SAKTI, PANAM PERUMAHAN GREEN T...
# 2    KO. CISEREH RT/RW 02/06 DESA KADU JAYA KECAMAT...
# ...

# %% [markdown]
# ###Menambakan Kolom Provinsi

# %%
APR_df2 = APR_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
APR_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota       Provinsi
# 0         BENGKULU       BENGKULU
# 1        PEKANBARU           RIAU
# 2        TANGERANG         BANTEN
# 3        TANGERANG         BANTEN
# 4        TANGERANG         BANTEN
# ..             ...            ...
# 298          BOGOR     JAWA BARAT
# 299          BOGOR     JAWA BARAT
# 300         BLITAR     JAWA TIMUR
# 301         BLITAR     JAWA TIMUR
# 302     YOGYAKARTA  DI YOGYAKARTA
#
# [303 rows x 2 columns]

# %% [markdown]
# ## MEI 2021

# %% [markdown]
# ###Load Dataset

# %%
MEI_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.MEI")
MEI_df2
# Out:
#      Tgl Order  Pemesanan                         Nama  \
# 0   2021-04-23     shopee              Shinta Oktarina
# 1   2021-04-23  bukalapak               Ohim Irwansyah
# 2   2021-04-23        web  marinus pandapotan simbolon
# 3   2021-04-23     shopee                         Isna
# 4   2021-04-23     shopee                         Isna
# ..         ...        ...                          ...
# 102 2021-05-07         wa                      ibu ana
# 103 2021-05-07         wa                Bayu Sulistyo
# 104 2021-05-07     shopee             Elsa Emelia Wati
# 105 2021-05-07         wa                 Ijaj Maulana
# 106        NaT        NaN                          NaN
#
#                                                Alamat   \
# 0    Dusun Paloh Paya, Gampong Ulee Gampong, Mutiar...
# 1    Serpong Garden Green Valley E-7 No. 12 A, Cibo...
# 2    Apartemen BELLAGIO RESIDENCE TOWER A Unit 22AF...
# 3    Bronggalan Sawah 4J No. 22 , KOTA SURABAYA, TA...
# ...

# %%
MEI_df2 = MEI_df2.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
MEI_df2['Alamat '] = MEI_df2['Alamat '].str.upper()
alamat_df = MEI_df2['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      DUSUN PALOH PAYA, GAMPONG ULEE GAMPONG, MUTIAR...
# 1      SERPONG GARDEN GREEN VALLEY E-7 NO. 12 A, CIBO...
# 2      APARTEMEN BELLAGIO RESIDENCE TOWER A UNIT 22AF...
# 3      BRONGGALAN SAWAH 4J NO. 22 , KOTA SURABAYA, TA...
# 4      BRONGGALAN SAWAH 4J NO. 22 , KOTA SURABAYA, TA...
#                              ...
# 101                                           YOGYAKARTA
# 102                                           YOGYAKARTA
# 103    JL PONDOK PESANTREN NO 3,WISMA ANTON SOEDJARWO...
# 104    JALAN MANYAR III NO.66 RT.21,HANDIL JAYA,JELUT...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
MEI_df2['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
MEI_df2
# Out:
#      Tgl Order  Pemesanan                         Nama  \
# 0   2021-04-23     shopee              Shinta Oktarina
# 1   2021-04-23  bukalapak               Ohim Irwansyah
# 2   2021-04-23        web  marinus pandapotan simbolon
# 3   2021-04-23     shopee                         Isna
# 4   2021-04-23     shopee                         Isna
# ..         ...        ...                          ...
# 101 2021-05-07         wa                      ibu ana
# 102 2021-05-07         wa                      ibu ana
# 103 2021-05-07         wa                Bayu Sulistyo
# 104 2021-05-07     shopee             Elsa Emelia Wati
# 105 2021-05-07         wa                 Ijaj Maulana
#
#                                                Alamat   \
# 0    DUSUN PALOH PAYA, GAMPONG ULEE GAMPONG, MUTIAR...
# 1    SERPONG GARDEN GREEN VALLEY E-7 NO. 12 A, CIBO...
# 2    APARTEMEN BELLAGIO RESIDENCE TOWER A UNIT 22AF...
# 3    BRONGGALAN SAWAH 4J NO. 22 , KOTA SURABAYA, TA...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
MEI_df2 = MEI_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
MEI_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#       Kabupaten/Kota       Provinsi
# 0              PIDIE           ACEH
# 1          TANGERANG         BANTEN
# 2          TANGERANG         BANTEN
# 3    JAKARTA SELATAN    DKI JAKARTA
# 4           SURABAYA     JAWA TIMUR
# ..               ...            ...
# 123       YOGYAKARTA  DI YOGYAKARTA
# 124            DEPOK     JAWA BARAT
# 125            JAMBI          JAMBI
# 126      TASIKMALAYA     JAWA BARAT
# 127      TASIKMALAYA     JAWA BARAT
#
# [128 rows x 2 columns]

# %% [markdown]
# ## JUNI 2021

# %% [markdown]
# ###Load Dataset

# %%
JUN_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.JUNI")
JUN_df2
# Out:
#      Tgl Order  Pemesanan                 Nama  \
# 0   2021-05-24     shopee         Yeni Apriani
# 1   2021-05-24     shopee   Oby Ismail Marzuki
# 2   2021-05-24     shopee                 Deta
# 3   2021-05-24  tokopedia  IRON TUAMAIN - RORI
# 4   2021-05-24  bukalapak         Novita Majid
# ..         ...        ...                  ...
# 241 2021-06-23         wa          boy hidayat
# 242 2021-06-23         wa          boy hidayat
# 243 2021-06-23         wa          boy hidayat
# 244 2021-06-23         wa          boy hidayat
# 245        NaT        NaN                  NaN
#
#                                                Alamat   \
# 0    Indomaret jalan Laswi Baleendah RT.03/RW.07 de...
# 1    Jalan Danau elok VI b1 n1, Rt 03 Rw 13 belakan...
# 2    Kantor DPP PKB , KOTA JAKARTA PUSAT, SENEN, DK...
# 3    RUMAH SUSUN TANAH ABANG Blok 39 Lantai 4 no. 4...
# 4    Jalan sultan hasanuddin, Badak 4, Rt.15, No.71...
# ..                                                 ...
# ...

# %%
JUN_df2 = JUN_df2.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
JUN_df2['Alamat ']=JUN_df2['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JUN_df2['Alamat '] = JUN_df2['Alamat '].str.upper()
alamat_df = JUN_df2['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      INDOMARET JALAN LASWI BALEENDAH RT.03/RW.07 DE...
# 1      JALAN DANAU ELOK VI B1 N1, RT 03 RW 13 BELAKAN...
# 2      KANTOR DPP PKB , KOTA JAKARTA PUSAT, SENEN, DK...
# 3      RUMAH SUSUN TANAH ABANG BLOK 39 LANTAI 4 NO. 4...
# 4      JALAN SULTAN HASANUDDIN, BADAK 4, RT.15, NO.71...
#                              ...
# 240    PERUMAHAN GRAND RISCON PADJAJARAN BLOK E8/NO.2...
# 241    PERUMAHAN GRAND RISCON PADJAJARAN BLOK E8/NO.2...
# 242    PERUMAHAN GRAND RISCON PADJAJARAN BLOK E8/NO.2...
# 243    PERUMAHAN GRAND RISCON PADJAJARAN BLOK E8/NO.2...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
JUN_df2['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JUN_df2
# Out:
#      Tgl Order  Pemesanan                 Nama  \
# 0   2021-05-24     shopee         Yeni Apriani
# 1   2021-05-24     shopee   Oby Ismail Marzuki
# 2   2021-05-24     shopee                 Deta
# 3   2021-05-24  tokopedia  IRON TUAMAIN - RORI
# 4   2021-05-24  bukalapak         Novita Majid
# ..         ...        ...                  ...
# 240 2021-06-23         wa          boy hidayat
# 241 2021-06-23         wa          boy hidayat
# 242 2021-06-23         wa          boy hidayat
# 243 2021-06-23         wa          boy hidayat
# 244 2021-06-23         wa          boy hidayat
#
#                                                Alamat   \
# 0    INDOMARET JALAN LASWI BALEENDAH RT.03/RW.07 DE...
# 1    JALAN DANAU ELOK VI B1 N1, RT 03 RW 13 BELAKAN...
# 2    KANTOR DPP PKB , KOTA JAKARTA PUSAT, SENEN, DK...
# 3    RUMAH SUSUN TANAH ABANG BLOK 39 LANTAI 4 NO. 4...
# 4    JALAN SULTAN HASANUDDIN, BADAK 4, RT.15, NO.71...
# ..                                                 ...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
JUN_df2 = JUN_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
JUN_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota     Provinsi
# 0          BANDUNG   JAWA BARAT
# 1          BANDUNG   JAWA BARAT
# 2    JAKARTA UTARA  DKI JAKARTA
# 3    JAKARTA PUSAT  DKI JAKARTA
# 4    JAKARTA PUSAT  DKI JAKARTA
# ..             ...          ...
# 293          BOGOR   JAWA BARAT
# 294          BOGOR   JAWA BARAT
# 295          BOGOR   JAWA BARAT
# 296          BOGOR   JAWA BARAT
# 297          BOGOR   JAWA BARAT
#
# [298 rows x 2 columns]

# %% [markdown]
# ## JULI 2021

# %% [markdown]
# ###Load Dataset

# %%
JULI_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.JULI")
JULI_df2
# Out:
#      Tgl Order Pemesan          Nama Penerima  \
# 0   2021-06-24  shopee              Cucu siti
# 1   2021-06-24  shopee              Cucu siti
# 2   2021-06-24  shopee              Cucu siti
# 3   2021-06-24  shopee              Cucu siti
# 4   2021-06-24  shopee      denny suci kurnia
# ..         ...     ...                    ...
# 251 2021-07-22      wa           Kurnia Putri
# 252 2021-07-22      wa               Rochimah
# 253 2021-07-22      wa                  Harry
# 254 2021-07-22      wa  ER Febri Angelina Nur
# 255        NaT     NaN                    NaN
#
#                                                Alamat   \
# 0     Kp. Cijambe kulon rt 2 rw 8 no 67 , desa cinu...
# 1     Kp. Cijambe kulon rt 2 rw 8 no 67 , desa cinu...
# 2     Kp. Cijambe kulon rt 2 rw 8 no 67 , desa cinu...
# 3     Kp. Cijambe kulon rt 2 rw 8 no 67 , desa cinu...
# 4    perumahan greenery permai blok f9 bojong gede ...
# ..                                                 ...
# ...

# %%
JULI_df2 = JULI_df2.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
JULI_df2['Alamat '] = JULI_df2['Alamat '].str.upper()
alamat_df = JULI_df2['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0       KP. CIJAMBE KULON RT 2 RW 8 NO 67 , DESA CINU...
# 1       KP. CIJAMBE KULON RT 2 RW 8 NO 67 , DESA CINU...
# 2       KP. CIJAMBE KULON RT 2 RW 8 NO 67 , DESA CINU...
# 3       KP. CIJAMBE KULON RT 2 RW 8 NO 67 , DESA CINU...
# 4      PERUMAHAN GREENERY PERMAI BLOK F9 BOJONG GEDE ...
#                              ...
# 250     JL. JATIPADANG RAYA GG NURUL IMAN RT 06 RW 03...
# 251    TAMAN HIJAU NO 371 LIPPO KARAWACI\n  KECAMATAN...
# 252    NERADA ESTATE BLOK C 2 NO.11, CIPAYUNG - CIPUT...
# 253    JL ANCOL TIMUR 14 NO 20, KOTA BANDUNG 40254\n ...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
JULI_df2['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JULI_df2
# Out:
#      Tgl Order Pemesan          Nama Penerima  \
# 0   2021-06-24  shopee              Cucu siti
# 1   2021-06-24  shopee              Cucu siti
# 2   2021-06-24  shopee              Cucu siti
# 3   2021-06-24  shopee              Cucu siti
# 4   2021-06-24  shopee      denny suci kurnia
# ..         ...     ...                    ...
# 250 2021-07-22      wa          venty hartiny
# 251 2021-07-22      wa           Kurnia Putri
# 252 2021-07-22      wa               Rochimah
# 253 2021-07-22      wa                  Harry
# 254 2021-07-22      wa  ER Febri Angelina Nur
#
#                                                Alamat   \
# 0     KP. CIJAMBE KULON RT 2 RW 8 NO 67 , DESA CINU...
# 1     KP. CIJAMBE KULON RT 2 RW 8 NO 67 , DESA CINU...
# 2     KP. CIJAMBE KULON RT 2 RW 8 NO 67 , DESA CINU...
# 3     KP. CIJAMBE KULON RT 2 RW 8 NO 67 , DESA CINU...
# 4    PERUMAHAN GREENERY PERMAI BLOK F9 BOJONG GEDE ...
# ..                                                 ...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
JULI_df2 = JULI_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
JULI_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota       Provinsi
# 0          BANDUNG     JAWA BARAT
# 1          BANDUNG     JAWA BARAT
# 2          BANDUNG     JAWA BARAT
# 3          BANDUNG     JAWA BARAT
# 4          BANDUNG     JAWA BARAT
# ..             ...            ...
# 328      TANGERANG         BANTEN
# 329      TANGERANG         BANTEN
# 330        BANDUNG     JAWA BARAT
# 331        BANDUNG     JAWA BARAT
# 332         SLEMAN  DI YOGYAKARTA
#
# [333 rows x 2 columns]

# %% [markdown]
# ##AGUSTUS 2021

# %% [markdown]
# ###Load Dataset

# %%
AGUS_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.AGUSTUS")
AGUS_df2
# Out:
#      Tgl Order    Pemesan             Nama Penerima  \
# 0   2021-07-23     shopee                     Helda
# 1   2021-07-23  bukalapak          Arsdo Simatupang
# 2   2021-07-23         wa  Delfta Tunjung Baswarani
# 3   2021-07-26     shopee                 R. Shelma
# 4   2021-07-26         wa                     aries
# ..         ...        ...                       ...
# 325 2021-08-23     shopee              Melinda Mega
# 326 2021-08-23     shopee              amal faradis
# 327 2021-08-23     shopee                    Afifah
# 328 2021-08-23        web                     Metta
# 329        NaT        NaN                       NaN
#
#                                                Alamat   \
# 0    Jl pangeran RT 5 no 46, KOTA BANJARMASIN, BANJ...
# 1    Taman Modern Jln. Sakura Blok E. 5 No. 27, Cak...
# 2    bu Siti Djahro (Ibu Makin) Jl. kolonel sugiono...
# 3    Komp Bumi Rancamanyar No.57, RT 03/RW 11, Desa...
# 4                                           yogyakarta
# ...

# %%
AGUS_df2 = AGUS_df2.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
AGUS_df2['Alamat '] = AGUS_df2['Alamat '].str.upper()
alamat_df = AGUS_df2['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      JL PANGERAN RT 5 NO 46, KOTA BANJARMASIN, BANJ...
# 1      TAMAN MODERN JLN. SAKURA BLOK E. 5 NO. 27, CAK...
# 2      BU SITI DJAHRO (IBU MAKIN) JL. KOLONEL SUGIONO...
# 3      KOMP BUMI RANCAMANYAR NO.57, RT 03/RW 11, DESA...
# 4                                             YOGYAKARTA
#                              ...
# 324    JL ANGKREK NO.117, PANGADUAN HEUBEUL, SUMEDANG...
# 325    DESA JATIREJO, DUSUN MIJIL, RT.1/RW.5, JATIREJ...
# 326    JL. PATIMURA KOMPLEK WISMA BUNGA BLOK C11 RT 5...
# 327    PERUM. SAPPHIRE RESIDENCE KARANGWANGKAL, ZAMRU...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
AGUS_df2['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
AGUS_df2
# Out:
#      Tgl Order    Pemesan             Nama Penerima  \
# 0   2021-07-23     shopee                     Helda
# 1   2021-07-23  bukalapak          Arsdo Simatupang
# 2   2021-07-23         wa  Delfta Tunjung Baswarani
# 3   2021-07-26     shopee                 R. Shelma
# 4   2021-07-26         wa                     aries
# ..         ...        ...                       ...
# 324 2021-08-23  bukalapak                Silvia Nur
# 325 2021-08-23     shopee              Melinda Mega
# 326 2021-08-23     shopee              amal faradis
# 327 2021-08-23     shopee                    Afifah
# 328 2021-08-23        web                     Metta
#
#                                                Alamat   \
# 0    JL PANGERAN RT 5 NO 46, KOTA BANJARMASIN, BANJ...
# 1    TAMAN MODERN JLN. SAKURA BLOK E. 5 NO. 27, CAK...
# 2    BU SITI DJAHRO (IBU MAKIN) JL. KOLONEL SUGIONO...
# 3    KOMP BUMI RANCAMANYAR NO.57, RT 03/RW 11, DESA...
# 4                                           YOGYAKARTA
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
AGUS_df2 = AGUS_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
AGUS_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota            Provinsi
# 0      BANJARMASIN  KALIMANTAN SELATAN
# 1    JAKARTA TIMUR         DKI JAKARTA
# 2         PEMALANG         JAWA TENGAH
# 3          BANDUNG          JAWA BARAT
# 4          BANDUNG          JAWA BARAT
# ..             ...                 ...
# 381       SUMEDANG          JAWA BARAT
# 382         KENDAL         JAWA TENGAH
# 383          JAMBI               JAMBI
# 384       BANYUMAS         JAWA TENGAH
# 385          DEPOK          JAWA BARAT
#
# [386 rows x 2 columns]

# %% [markdown]
# ## SEPTEMBER 2021

# %% [markdown]
# ###Load Dataset

# %%
SEPT_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.SEPTEMBER")
SEPT_df2
# Out:
#      Tgl Order    Pemesan                 Nama Penerima  \
# 0   2021-08-24     shopee          Dyla Putri Salsabila
# 1   2021-08-24     shopee                      Dyah ayu
# 2   2021-08-24     shopee   Sherly Oktarianti / Ibu sus
# 3   2021-08-24  tokopedia  ladia Rimba Angkasa Sumarwan
# 4   2021-08-24  tokopedia                 Fatma fatimah
# ..         ...        ...                           ...
# 475 2021-09-23  tokopedia                Ismu Bahaiduri
# 476 2021-09-23         wa         PAJAK ITU MUDAH STORE
# 477 2021-09-23         wa         PAJAK ITU MUDAH STORE
# 478 2021-09-23         wa         PAJAK ITU MUDAH STORE
# 479        NaT        NaN                           NaN
#
#                                                Alamat   \
# 0    Graha bukit raya 3 blok E3 no 31 , KAB. BANDUN...
# 1    Gedawang pesona asri blok B no.7A rt 02/07, KO...
# 2    Jl. Selat panjang GG. Wartawan 3 no. 08, KOTA ...
# 3    Nyaen, Pandowoharjo, Kec. Sleman, Kabupaten Sl...
# ...

# %%
SEPT_df2 = SEPT_df2.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
SEPT_df2['Alamat '] = SEPT_df2['Alamat '].str.upper()
alamat_df = SEPT_df2['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      GRAHA BUKIT RAYA 3 BLOK E3 NO 31 , KAB. BANDUN...
# 1      GEDAWANG PESONA ASRI BLOK B NO.7A RT 02/07, KO...
# 2      JL. SELAT PANJANG GG. WARTAWAN 3 NO. 08, KOTA ...
# 3      NYAEN, PANDOWOHARJO, KEC. SLEMAN, KABUPATEN SL...
# 4      VILLA GRANDYS BLOK D3 JL PERSAHABATAN 7 RT.10 ...
#                              ...
# 474    AKADEMI KESEHATAN JOHN PAUL II\nJL. PERMATA I ...
# 475    VILLA SERPONG, JALAN KENCANA VIII BLOK C.8 NOM...
# 476                                                BOGOR
# 477                                                BOGOR
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
SEPT_df2['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
SEPT_df2
# Out:
#      Tgl Order    Pemesan                 Nama Penerima  \
# 0   2021-08-24     shopee          Dyla Putri Salsabila
# 1   2021-08-24     shopee                      Dyah ayu
# 2   2021-08-24     shopee   Sherly Oktarianti / Ibu sus
# 3   2021-08-24  tokopedia  ladia Rimba Angkasa Sumarwan
# 4   2021-08-24  tokopedia                 Fatma fatimah
# ..         ...        ...                           ...
# 474 2021-09-23        web                 Zevera Erinna
# 475 2021-09-23  tokopedia                Ismu Bahaiduri
# 476 2021-09-23         wa         PAJAK ITU MUDAH STORE
# 477 2021-09-23         wa         PAJAK ITU MUDAH STORE
# 478 2021-09-23         wa         PAJAK ITU MUDAH STORE
#
#                                                Alamat   \
# 0    GRAHA BUKIT RAYA 3 BLOK E3 NO 31 , KAB. BANDUN...
# 1    GEDAWANG PESONA ASRI BLOK B NO.7A RT 02/07, KO...
# 2    JL. SELAT PANJANG GG. WARTAWAN 3 NO. 08, KOTA ...
# 3    NYAEN, PANDOWOHARJO, KEC. SLEMAN, KABUPATEN SL...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
SEPT_df2 = SEPT_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
SEPT_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota          Provinsi
# 0    BANDUNG BARAT        JAWA BARAT
# 1         SEMARANG       JAWA TENGAH
# 2         SEMARANG       JAWA TENGAH
# 3        PONTIANAK  KALIMANTAN BARAT
# 4           SLEMAN     DI YOGYAKARTA
# ..             ...               ...
# 586          BOGOR        JAWA BARAT
# 587          BOGOR        JAWA BARAT
# 588          BOGOR        JAWA BARAT
# 589          BOGOR        JAWA BARAT
# 590          BOGOR        JAWA BARAT
#
# [591 rows x 2 columns]

# %% [markdown]
# ## OKTOBER 2021

# %% [markdown]
# ###Load Dataset

# %%
OKT_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.OKTOBER")
OKT_df2
# Out:
#      Tgl Order Pemesan                    Nama Penerima  \
# 0   2021-09-24  lazada             Bunga Septria Vionit
# 1   2021-09-24     web                    YUDI HERDIANA
# 2   2021-09-24      wa                          bambang
# 3   2021-09-24     web                 Mumtazah Syarafi
# 4   2021-09-24      wa                   Anita Ramadona
# ..         ...     ...                              ...
# 292 2021-10-22      wa                     Mifta Rahman
# 293 2021-10-22      wa                     Mifta Rahman
# 294 2021-10-22      wa                            sisca
# 295 2021-10-22      wa                        Rahmawati
# 296 2021-10-22      wa  Diyana (kontrakan Haji Masduki)
#
#                                                Alamat   \
# 0    Pasir Harja RT/RW 15/10 Jawa Barat Kab. Subang...
# 1    PT. ARTHABINTEK INDUSTRI\nJl. Cikarang - Cibar...
# 2                                Jl Jati indah I No 12
# 3    Jl. Ketib Anom No.1 Blok Rebo, Maja Selatan RT...
# ...

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
OKT_df2['Alamat '] = OKT_df2['Alamat '].str.upper()
alamat_df = OKT_df2['Alamat ']
alamat_df
# Out:
# 0      PASIR HARJA RT/RW 15/10 JAWA BARAT KAB. SUBANG...
# 1      PT. ARTHABINTEK INDUSTRI\nJL. CIKARANG - CIBAR...
# 2                                  JL JATI INDAH I NO 12
# 3      JL. KETIB ANOM NO.1 BLOK REBO, MAJA SELATAN RT...
# 4      LESEHAN ZAKI, JLN.LINTAS SUMATERA UTARA, KEL.L...
#                              ...
# 292    JALAN PERTANI GG RAHUL NO 16\n  KECAMATAN: PON...
# 293    JALAN PERTANI GG RAHUL NO 16\n  KECAMATAN: PON...
# 294     GRAHA FAMILY Y-28, EMERALD PLACE . WIYUNG, WI...
# 295    JL.JEND A.H NASUTION NO.G 37 ( PRODI S1 KESEHA...
# 296    JLN. TAWANG MANGU KM 11 RT 012 RW 03 KELURAHAN...
# Name: Alamat , Length: 297, dtype: object

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
OKT_df2['Kabupaten/Kota'] = data_alamat

# %%
OKT_df2
# Out:
#      Tgl Order Pemesan                    Nama Penerima  \
# 0   2021-09-24  lazada             Bunga Septria Vionit
# 1   2021-09-24     web                    YUDI HERDIANA
# 2   2021-09-24      wa                          bambang
# 3   2021-09-24     web                 Mumtazah Syarafi
# 4   2021-09-24      wa                   Anita Ramadona
# ..         ...     ...                              ...
# 292 2021-10-22      wa                     Mifta Rahman
# 293 2021-10-22      wa                     Mifta Rahman
# 294 2021-10-22      wa                            sisca
# 295 2021-10-22      wa                        Rahmawati
# 296 2021-10-22      wa  Diyana (kontrakan Haji Masduki)
#
#                                                Alamat   \
# 0    PASIR HARJA RT/RW 15/10 JAWA BARAT KAB. SUBANG...
# 1    PT. ARTHABINTEK INDUSTRI\nJL. CIKARANG - CIBAR...
# 2                                JL JATI INDAH I NO 12
# 3    JL. KETIB ANOM NO.1 BLOK REBO, MAJA SELATAN RT...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
OKT_df2 = OKT_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
OKT_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota           Provinsi
# 0           SUBANG         JAWA BARAT
# 1           BEKASI         JAWA BARAT
# 2           BEKASI         JAWA BARAT
# 3        UNDEFINED          UNDEFINED
# 4       MAJALENGKA         JAWA BARAT
# ..             ...                ...
# 402      PONTIANAK   KALIMANTAN BARAT
# 403      PONTIANAK   KALIMANTAN BARAT
# 404       SURABAYA         JAWA TIMUR
# 405        KENDARI  SULAWESI TENGGARA
# 406  JAKARTA BARAT        DKI JAKARTA
#
# [407 rows x 2 columns]

# %% [markdown]
# ## NOVEMBER 2021

# %% [markdown]
# ###Load Dataset

# %%
NOV_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.NOVEMBER")
NOV_df2
# Out:
#      Tgl Order Pemesan           Nama Penerima  \
# 0   2021-10-25  shopee     ALIF LAYLA SYA'BANI
# 1   2021-10-25  shopee     Nining Ratnaningsih
# 2   2021-10-25  shopee     Nining Ratnaningsih
# 3   2021-10-25  shopee  Dominikus Niko Dasilva
# 4   2021-10-25  shopee             Anisa Santi
# ..         ...     ...                     ...
# 984 2021-11-23      wa                   yudha
# 985 2021-11-23      wa                   yudha
# 986 2021-11-23      wa                   yudha
# 987 2021-11-23      wa                   yudha
# 988 2021-11-23      wa                   yudha
#
#                                                Alamat   \
# 0    Karanggayam Sitimulyo Piyungan Pondok Pesantre...
# 1    Rs. Paru dr. HA ROTINSULU Bandung Jl. Bukit Ja...
# 2    Rs. Paru dr. HA ROTINSULU Bandung Jl. Bukit Ja...
# 3    Belakang gereja kaiserea BTN kolhua ( blok i n...
# 4    Kp. Cisalak rt 01/14 desa cibunian kec. Pamija...
# ..                                                 ...
# ...

# %% [markdown]
# ###Memisahkan Kabupaten/kota dari Alamat

# %%
NOV_df2['Alamat '] = NOV_df2['Alamat '].str.upper()
alamat_df = NOV_df2['Alamat ']
alamat_df
# Out:
# 0      KARANGGAYAM SITIMULYO PIYUNGAN PONDOK PESANTRE...
# 1      RS. PARU DR. HA ROTINSULU BANDUNG JL. BUKIT JA...
# 2      RS. PARU DR. HA ROTINSULU BANDUNG JL. BUKIT JA...
# 3      BELAKANG GEREJA KAISEREA BTN KOLHUA ( BLOK I N...
# 4      KP. CISALAK RT 01/14 DESA CIBUNIAN KEC. PAMIJA...
#                              ...
# 984                                             SURABAYA
# 985                                             SURABAYA
# 986                                             SURABAYA
# 987                                             SURABAYA
# 988                                             SURABAYA
# Name: Alamat , Length: 989, dtype: object

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
NOV_df2['Kabupaten/Kota'] = data_alamat

# %%
NOV_df2
# Out:
#      Tgl Order Pemesan           Nama Penerima  \
# 0   2021-10-25  shopee     ALIF LAYLA SYA'BANI
# 1   2021-10-25  shopee     Nining Ratnaningsih
# 2   2021-10-25  shopee     Nining Ratnaningsih
# 3   2021-10-25  shopee  Dominikus Niko Dasilva
# 4   2021-10-25  shopee             Anisa Santi
# ..         ...     ...                     ...
# 984 2021-11-23      wa                   yudha
# 985 2021-11-23      wa                   yudha
# 986 2021-11-23      wa                   yudha
# 987 2021-11-23      wa                   yudha
# 988 2021-11-23      wa                   yudha
#
#                                                Alamat   \
# 0    KARANGGAYAM SITIMULYO PIYUNGAN PONDOK PESANTRE...
# 1    RS. PARU DR. HA ROTINSULU BANDUNG JL. BUKIT JA...
# 2    RS. PARU DR. HA ROTINSULU BANDUNG JL. BUKIT JA...
# 3    BELAKANG GEREJA KAISEREA BTN KOLHUA ( BLOK I N...
# 4    KP. CISALAK RT 01/14 DESA CIBUNIAN KEC. PAMIJA...
# ..                                                 ...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
NOV_df2 = NOV_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
NOV_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#      Kabupaten/Kota       Provinsi
# 0            BANTUL  DI YOGYAKARTA
# 1           BANDUNG     JAWA BARAT
# 2           BANDUNG     JAWA BARAT
# 3           BANDUNG     JAWA BARAT
# 4           BANDUNG     JAWA BARAT
# ...             ...            ...
# 1057       SURABAYA     JAWA TIMUR
# 1058       SURABAYA     JAWA TIMUR
# 1059       SURABAYA     JAWA TIMUR
# 1060       SURABAYA     JAWA TIMUR
# 1061       SURABAYA     JAWA TIMUR
#
# [1062 rows x 2 columns]

# %% [markdown]
# ## DESEMBER 2021

# %% [markdown]
# ###Load Dataset

# %%
DES_df2 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2021-terbaru-ed.xlsx?raw=true", sheet_name = "M.DESEMBER")
DES_df2
# Out:
#      Tgl Order Pemesan         Nama Penerima  \
# 0   2021-11-24  shopee            Sri Ranita
# 1   2021-11-24  shopee                Teh Ai
# 2   2021-11-25      wa                   boy
# 3   2021-11-25      wa                   boy
# 4   2021-11-25      wa                   boy
# ..         ...     ...                   ...
# 385 2021-12-23  shopee                  ALDI
# 386 2021-12-23  shopee                   Ria
# 387 2021-12-23      wa       Laode Mondolalo
# 388 2021-12-23      wa       Laode Mondolalo
# 389 2021-12-23      wa  Zuarnida Simanjuntak
#
#                                                Alamat   \
# 0    Jalan Mandala 5 No.12, RT.6/RW.9, Cililitan Ke...
# 1    Blok Cipadung No. 59, RT.01/RW.01, Karyamukti,...
# 2                                              jakarta
# 3                                              jakarta
# 4                                              jakarta
# ..                                                 ...
# ...

# %% [markdown]
# ###Memisahkan Kabupaten/kota dari Alamat

# %%
DES_df2['Alamat '] = DES_df2['Alamat '].str.upper()
alamat_df = DES_df2['Alamat ']
alamat_df
# Out:
# 0      JALAN MANDALA 5 NO.12, RT.6/RW.9, CILILITAN KE...
# 1      BLOK CIPADUNG NO. 59, RT.01/RW.01, KARYAMUKTI,...
# 2                                                JAKARTA
# 3                                                JAKARTA
# 4                                                JAKARTA
#                              ...
# 385    PERUMAHAN PERMATA BUKIT RAYA, JLN. BHAKTI HUSA...
# 386    SULTAN ALAUDDIN 2, LORONG 2D, MANGASA, TAMALAT...
# 387    MAN 1 KEBUMEN - JL. CINCIN KOTA NO.44, WATUBAR...
# 388    MAN 1 KEBUMEN - JL. CINCIN KOTA NO.44, WATUBAR...
# 389    WARUNG OPPUNG JOJOR NO. 10 DESA GUR-GUR AEKRAJ...
# Name: Alamat , Length: 390, dtype: object

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
DES_df2['Kabupaten/Kota'] = data_alamat

# %%
DES_df2
# Out:
#      Tgl Order Pemesan         Nama Penerima  \
# 0   2021-11-24  shopee            Sri Ranita
# 1   2021-11-24  shopee                Teh Ai
# 2   2021-11-25      wa                   boy
# 3   2021-11-25      wa                   boy
# 4   2021-11-25      wa                   boy
# ..         ...     ...                   ...
# 385 2021-12-23  shopee                  ALDI
# 386 2021-12-23  shopee                   Ria
# 387 2021-12-23      wa       Laode Mondolalo
# 388 2021-12-23      wa       Laode Mondolalo
# 389 2021-12-23      wa  Zuarnida Simanjuntak
#
#                                                Alamat   \
# 0    JALAN MANDALA 5 NO.12, RT.6/RW.9, CILILITAN KE...
# 1    BLOK CIPADUNG NO. 59, RT.01/RW.01, KARYAMUKTI,...
# 2                                              JAKARTA
# 3                                              JAKARTA
# 4                                              JAKARTA
# ..                                                 ...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
DES_df2 = DES_df2.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
DES_df2.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota          Provinsi
# 0    JAKARTA TIMUR       DKI JAKARTA
# 1       MAJALENGKA        JAWA BARAT
# 2        UNDEFINED         UNDEFINED
# 3        UNDEFINED         UNDEFINED
# 4        UNDEFINED         UNDEFINED
# ..             ...               ...
# 500      PEKANBARU              RIAU
# 501       MAKASSAR  SULAWESI SELATAN
# 502        KEBUMEN       JAWA TENGAH
# 503        KEBUMEN       JAWA TENGAH
# 504   TOBA SAMOSIR    SUMATERA UTARA
#
# [505 rows x 2 columns]

# %% [markdown]
# ##Menggabungkan Seluruh Sheet menjadi satu DataFrame dan Check DataFrame-nya

# %%
df2_concat = pd.concat([JAN_df2,FEB_df2,MAR_df2,APR_df2,MEI_df2,JUN_df2,JULI_df2,AGUS_df2,SEPT_df2,OKT_df2,NOV_df2,DES_df2])

df2_concat
# Out:
#      Tgl Order Pemesanan               Nama  \
# 0   2020-12-23        wa   Milka Atika Sari
# 1   2020-12-23  langsung        nur hidayat
# 2   2020-12-23        wa       gani wiharso
# 3   2020-12-23        wa       gani wiharso
# 4   2020-12-24    shopee  Nabiladiahirianti
# ..         ...       ...                ...
# 500 2021-12-23       NaN                NaN
# 501 2021-12-23       NaN                NaN
# 502 2021-12-23       NaN                NaN
# 503 2021-12-23       NaN                NaN
# 504 2021-12-23       NaN                NaN
#
#                                                Alamat   \
# 0    JL. YUDISTIRA II, KALIKUNING RT. 03 RW. 09, JO...
# 1                                           YOGYAKARTA
# 2    PERUM ANEKA ELOK BLOK D 3 NO.40 RT.005 RW 09 K...
# 3    PERUM ANEKA ELOK BLOK D 3 NO.40 RT.005 RW 09 K...
# 4    DEPAN UPTD SUKONATAR ADA GANG MASUK. LURUS 100...
# ..                                                 ...
# ...

# %%
df2_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5214 entries, 0 to 504
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Tgl Order                      5214 non-null   datetime64[ns]
#  1   Pemesanan                      1930 non-null   object
#  2   Nama                           1930 non-null   object
#  3   Alamat                         5214 non-null   object
#  4   judul buku                     5214 non-null   object
#  5   Pengarang                      5211 non-null   object
#  6   jumlah pesanan                 5214 non-null   object
#  7   harga                          1930 non-null   float64
#  8   jumlah penjualan               5214 non-null   float64
#  9   discount                       2369 non-null   float64
#  10  harga setelah diskon           5214 non-null   float64
#  11  ongkos kirim                   2071 non-null   float64
# ...

# %% [markdown]
# ##Memperbaiki format dari fitur-fitur yang ada pada Dataset 2

# %%
df2_concat.columns
# Out:
# Index(['Tgl Order', 'Pemesanan', 'Nama', 'Alamat ', 'judul buku ', 'Pengarang',
#        'jumlah pesanan ', 'harga', 'jumlah penjualan', 'discount',
#        'harga setelah diskon', 'ongkos kirim', 'Service fee', 'total',
#        'order via', 'nomor transaksi (invoice dll)', 'KET', 'tgl kirim ',
#        'resi ', 'Total per judul', 'Royalti', 'Total Real', 'Diskon',
#        'Kabupaten/Kota', 'Provinsi', 'Pemesan', 'Nama Penerima',
#        'harga satuan '],
#       dtype='object')

# %%
df2_concat.rename(columns={'judul buku ': 'Judul Buku','jumlah pesanan ':'Jumlah Pesanan','total': 'Total Pembayaran'}, inplace=True)

# %%
df2_concat['Judul Buku'] = df2_concat['Judul Buku'].str.title()
df2_concat['Judul Buku']
# Out:
# 0      Upaya Mengoptimalkan Desa Sawarna, Banten Seba...
# 1      Analisis Data Menggunakan Stata Se 14 (Panduan...
# 2                     Dasar-Dasar Akuntansi Untuk Pemula
# 3      Ekonomi Mikro, Analisis Dan Pendekatan Praktis...
# 4      Linguistik Mikro (Kajian Internal Bahasa Dan P...
#                              ...
# 500    Etika Peserta Didik: Menurut Syaikh Muhammad B...
# 501    Literasi Matematika Upaya Meningkatkan Kemampu...
# 502    Bukan Kota Tanpa Masa Lalu: Dinamika Sosial Ek...
# 503    Wetan Kali Kulon Kali Mengenang Kabupaten Kara...
# 504                            Strategi Belajar Mengajar
# Name: Judul Buku, Length: 5214, dtype: object

# %%
df2_concat['Jumlah Pesanan'] = df2_concat['Jumlah Pesanan'].astype(str).astype(int)

# %% [markdown]
# ##Memisahkan Month dan Year dari Tgl Order pada Dataset 2

# %%
df2_concat['Month'] = pd.DatetimeIndex(df2_concat['Tgl Order']).month

# %%
df2_concat['Year'] = pd.DatetimeIndex(df2_concat['Tgl Order']).year

# %%
df2_concat
# Out:
#      Tgl Order Pemesanan               Nama  \
# 0   2020-12-23        wa   Milka Atika Sari
# 1   2020-12-23  langsung        nur hidayat
# 2   2020-12-23        wa       gani wiharso
# 3   2020-12-23        wa       gani wiharso
# 4   2020-12-24    shopee  Nabiladiahirianti
# ..         ...       ...                ...
# 500 2021-12-23       NaN                NaN
# 501 2021-12-23       NaN                NaN
# 502 2021-12-23       NaN                NaN
# 503 2021-12-23       NaN                NaN
# 504 2021-12-23       NaN                NaN
#
#                                                Alamat   \
# 0    JL. YUDISTIRA II, KALIKUNING RT. 03 RW. 09, JO...
# 1                                           YOGYAKARTA
# 2    PERUM ANEKA ELOK BLOK D 3 NO.40 RT.005 RW 09 K...
# 3    PERUM ANEKA ELOK BLOK D 3 NO.40 RT.005 RW 09 K...
# 4    DEPAN UPTD SUKONATAR ADA GANG MASUK. LURUS 100...
# ..                                                 ...
# ...

# %% [markdown]
# ##Memisahkan Fitur-Fitur yang diperlukan untuk Analisa kedalam sebuah DataFrame Baru pada Dataset 2

# %%
df21 = df2_concat.loc[:,['Year', 'Month', 'Kabupaten/Kota', 'Provinsi','Judul Buku','Jumlah Pesanan', 'Total Pembayaran']]
df21
# Out:
#      Year  Month Kabupaten/Kota          Provinsi  \
# 0    2020     12         KLATEN       JAWA TENGAH
# 1    2020     12     YOGYAKARTA     DI YOGYAKARTA
# 2    2020     12  JAKARTA TIMUR       DKI JAKARTA
# 3    2020     12  JAKARTA TIMUR       DKI JAKARTA
# 4    2020     12     BANYUWANGI        JAWA TIMUR
# ..    ...    ...            ...               ...
# 500  2021     12      PEKANBARU              RIAU
# 501  2021     12       MAKASSAR  SULAWESI SELATAN
# 502  2021     12        KEBUMEN       JAWA TENGAH
# 503  2021     12        KEBUMEN       JAWA TENGAH
# 504  2021     12   TOBA SAMOSIR    SUMATERA UTARA
#
#                                             Judul Buku  Jumlah Pesanan  \
# 0    Upaya Mengoptimalkan Desa Sawarna, Banten Seba...               1
# 1    Analisis Data Menggunakan Stata Se 14 (Panduan...               1
# 2                   Dasar-Dasar Akuntansi Untuk Pemula               1
# 3    Ekonomi Mikro, Analisis Dan Pendekatan Praktis...               1
# ...

# %%
df21.dtypes
# Out:
# Year                  int64
# Month                 int64
# Kabupaten/Kota       object
# Provinsi             object
# Judul Buku           object
# Jumlah Pesanan        int64
# Total Pembayaran    float64
# dtype: object

# %% [markdown]
# #DATASET 3 : ORDER 2020

# %% [markdown]
# ##JANUARI 2020

# %% [markdown]
# ###Load Dataset

# %%
JAN_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M.JANUARI")
JAN_df3
# Out:
#         No  Tgl Order       Pemesan  Nama Penerima        Alamat   \
# 0      1.0 2019-12-30        Sherly            NaN  Lubuk linggau
# 1      2.0 2019-12-30         Nelis            NaN        Bandung
# 2      3.0 2019-12-30         Richo            NaN       Sidoarjo
# 3      4.0 2020-01-03     Anggi Dwi            NaN        Cianjur
# 4      5.0 2020-01-08  Siti Ridhani            NaN       Sidoarjo
# ..     ...        ...           ...            ...            ...
# 133  134.0 2020-01-27          Dian            NaN      Surakarta
# 134  135.0 2020-01-27          Dian            NaN      Surakarta
# 135  136.0 2020-01-27       M Kemal            NaN       Kotabaru
# 136  137.0 2020-01-27       M Kemal            NaN       Kotabaru
# 137    NaN        NaT           NaN            NaN            NaN
#
#                                            judul buku   \
# 0    Peningkatan Kinerja Sumber Daya Manusia Melalu...
# 1    Modul Edukasi Gizi Pencegahan dan Penanggulang...
# ...

# %%
JAN_df3 = JAN_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
JAN_df3['Alamat ']=JAN_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JAN_df3['Alamat '] = JAN_df3['Alamat '].str.upper()
alamat_df = JAN_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      LUBUK LINGGAU
# 1            BANDUNG
# 2           SIDOARJO
# 3            CIANJUR
# 4           SIDOARJO
#            ...
# 132        SURAKARTA
# 133        SURAKARTA
# 134        SURAKARTA
# 135         KOTABARU
# 136         KOTABARU
# Name: Alamat , Length: 137, dtype: object

# %%
def kab(alamat):
  kabupaten=''
  alamat_list = alamat.to_list()
  ls_kab = list()
  for i in range(len(alamat_list)):
    for j in list_kab:
      if (str(j) == str(alamat_list[i])):
        #print(j)
        #print(i)
        kabupaten = j
        break
      else:
        # jika tidak ada dalam list, maka ambil kolom kabupaten/kota
        kabupaten = 'UNDEFINED'
    ls_kab.append(kabupaten)
  
  #print(ls_kab)
  return ls_kab

# %%
ls = list()
ls = kab(JAN_df3['Alamat '])

# %%
JAN_df3['Kabupaten/Kota'] = ls
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JAN_df3
# Out:
#         No  Tgl Order       Pemesan  Nama Penerima        Alamat   \
# 0      1.0 2019-12-30        Sherly            NaN  LUBUK LINGGAU
# 1      2.0 2019-12-30         Nelis            NaN        BANDUNG
# 2      3.0 2019-12-30         Richo            NaN       SIDOARJO
# 3      4.0 2020-01-03     Anggi Dwi            NaN        CIANJUR
# 4      5.0 2020-01-08  Siti Ridhani            NaN       SIDOARJO
# ..     ...        ...           ...            ...            ...
# 132  133.0 2020-01-27          Dian            NaN      SURAKARTA
# 133  134.0 2020-01-27          Dian            NaN      SURAKARTA
# 134  135.0 2020-01-27          Dian            NaN      SURAKARTA
# 135  136.0 2020-01-27       M Kemal            NaN       KOTABARU
# 136  137.0 2020-01-27       M Kemal            NaN       KOTABARU
#
#                                            judul buku   \
# 0    Peningkatan Kinerja Sumber Daya Manusia Melalu...
# 1    Modul Edukasi Gizi Pencegahan dan Penanggulang...
# ...

# %% [markdown]
# ###Menambahkan  Kolom Provinsi

# %%
JAN_df3 = JAN_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
JAN_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota            Provinsi
# 0    LUBUK LINGGAU    SUMATERA SELATAN
# 1          BANDUNG          JAWA BARAT
# 2          BANDUNG          JAWA BARAT
# 3         SIDOARJO          JAWA TIMUR
# 4          CIANJUR          JAWA BARAT
# ..             ...                 ...
# 158      SURAKARTA         JAWA TENGAH
# 159      SURAKARTA         JAWA TENGAH
# 160      SURAKARTA         JAWA TENGAH
# 161       KOTABARU  KALIMANTAN SELATAN
# 162       KOTABARU  KALIMANTAN SELATAN
#
# [163 rows x 2 columns]

# %% [markdown]
# ## FEBRUARI 2020

# %% [markdown]
# ###Load Dataset

# %%
FEB_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M.FEBRUARI")
FEB_df3
# Out:
#         No  Tgl Order                 Pemesan           Nama Penerima  \
# 0      1.0 2020-01-28            Asyrul Fikri            Asyrul Fikri
# 1      2.0 2020-01-28  Chitalia (Desy kurnia)  Chitalia (Desy kurnia)
# 2      3.0 2020-01-28                  Hendry                  Hendry
# 3      4.0 2020-01-28                     Evi                     Evi
# 4      5.0 2020-01-28            Syarif iqbal            Syarif iqbal
# ..     ...        ...                     ...                     ...
# 170  173.0 2020-02-24        Fauzian Maulidah        Fauzian Maulidah
# 171  174.0 2020-02-24                  Hayyun                  Hayyun
# 172  175.0 2020-02-24           Dimas Prakoso           Dimas Prakoso
# 173  176.0 2020-02-24                 Sunardi                 Sunardi
# 174    NaN        NaT                     NaN                     NaN
#
#      Alamat   No HP                                        judul buku   \
# ...

# %%
FEB_df3 = FEB_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan  Kabupaten/Kota dari Alamat

# %%
FEB_df3['Alamat ']=FEB_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
FEB_df3['Alamat '] = FEB_df3['Alamat '].str.upper()
alamat_df = FEB_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      NAN
# 1      NAN
# 2      NAN
# 3      NAN
# 4      NAN
#       ...
# 169    NAN
# 170    NAN
# 171    NAN
# 172    NAN
# 173    NAN
# Name: Alamat , Length: 174, dtype: object

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
FEB_df3['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
FEB_df3
# Out:
#         No  Tgl Order                 Pemesan           Nama Penerima Alamat   \
# 0      1.0 2020-01-28            Asyrul Fikri            Asyrul Fikri     NAN
# 1      2.0 2020-01-28  Chitalia (Desy kurnia)  Chitalia (Desy kurnia)     NAN
# 2      3.0 2020-01-28                  Hendry                  Hendry     NAN
# 3      4.0 2020-01-28                     Evi                     Evi     NAN
# 4      5.0 2020-01-28            Syarif iqbal            Syarif iqbal     NAN
# ..     ...        ...                     ...                     ...     ...
# 169  172.0 2020-02-24        Sarah Hermayanti        Sarah Hermayanti     NAN
# 170  173.0 2020-02-24        Fauzian Maulidah        Fauzian Maulidah     NAN
# 171  174.0 2020-02-24                  Hayyun                  Hayyun     NAN
# 172  175.0 2020-02-24           Dimas Prakoso           Dimas Prakoso     NAN
# 173  176.0 2020-02-24                 Sunardi                 Sunardi     NAN
#
# ...

# %% [markdown]
# ###Menambahkan  Kolom Provinsi

# %%
FEB_df3 = FEB_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
FEB_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota   Provinsi
# 0        UNDEFINED  UNDEFINED
# 1        UNDEFINED  UNDEFINED
# 2        UNDEFINED  UNDEFINED
# 3        UNDEFINED  UNDEFINED
# 4        UNDEFINED  UNDEFINED
# ..             ...        ...
# 169      UNDEFINED  UNDEFINED
# 170      UNDEFINED  UNDEFINED
# 171      UNDEFINED  UNDEFINED
# 172      UNDEFINED  UNDEFINED
# 173      UNDEFINED  UNDEFINED
#
# [174 rows x 2 columns]

# %% [markdown]
# ## MARET 2020

# %% [markdown]
# ###Load Dataset

# %%
MAR_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M. MARET")
MAR_df3
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:211: UserWarning: Cell T28 is marked as a date but the serial value 1404902000006560 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
#       No  Tgl Order           Pemesan  Nama Penerima        Alamat   \
# 0      1 2020-02-25  Siti nurhandalia            NaN          Bogor
# 1      2 2020-02-25              tejo            NaN      Tangerang
# 2      3 2020-02-25            ervita            NaN       Wonosobo
# 3      4 2020-02-25             Liana            NaN  Jakarta Timur
# 4      5 2020-02-25             Cahya            NaN         Bantul
# ..   ...        ...               ...            ...            ...
# 222  223 2020-03-20       Leo Chandra            NaN  Lubuk Linggau
# 223  224 2020-03-20                WA            NaN       Karawang
# 224  225 2020-03-20           Atria T            NaN      Pontianak
# ...

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
MAR_df3['Alamat ']=MAR_df3['Alamat '].apply(str)

# %%
MAR_df3['Alamat '] = MAR_df3['Alamat '].str.upper()
alamat_df = MAR_df3['Alamat ']
alamat_df
# Out:
# 0              BOGOR
# 1          TANGERANG
# 2           WONOSOBO
# 3      JAKARTA TIMUR
# 4             BANTUL
#            ...
# 222    LUBUK LINGGAU
# 223         KARAWANG
# 224        PONTIANAK
# 225        PONTIANAK
# 226        PONTIANAK
# Name: Alamat , Length: 227, dtype: object

# %%
def kab(alamat):
  kabupaten=''
  alamat_list = alamat.to_list()
  ls_kab = list()
  for i in range(len(alamat_list)):
    for j in list_kab:
      if (str(j) == str(alamat_list[i])):
        #print(j)
        #print(i)
        kabupaten = j
        break
      else:
        # jika tidak ada dalam list, maka ambil kolom kabupaten/kota
        kabupaten = 'UNDEFINED'
    ls_kab.append(kabupaten)
  
  #print(ls_kab)
  return ls_kab

# %%
ls = list()
ls = kab(MAR_df3['Alamat '])

# %%
MAR_df3['Kabupaten/Kota'] = ls

# %%
MAR_df3
# Out:
#       No  Tgl Order           Pemesan  Nama Penerima        Alamat   \
# 0      1 2020-02-25  Siti nurhandalia            NaN          BOGOR
# 1      2 2020-02-25              tejo            NaN      TANGERANG
# 2      3 2020-02-25            ervita            NaN       WONOSOBO
# 3      4 2020-02-25             Liana            NaN  JAKARTA TIMUR
# 4      5 2020-02-25             Cahya            NaN         BANTUL
# ..   ...        ...               ...            ...            ...
# 222  223 2020-03-20       Leo Chandra            NaN  LUBUK LINGGAU
# 223  224 2020-03-20                WA            NaN       KARAWANG
# 224  225 2020-03-20           Atria T            NaN      PONTIANAK
# 225  226 2020-03-20           Atria T            NaN      PONTIANAK
# 226  227 2020-03-20           Atria T            NaN      PONTIANAK
#
#                                            judul buku   \
# 0                      Buku Ajar Keperawatan Gerontik
# ...

# %% [markdown]
# ###Manambkan Kolom Provinsi

# %%
MAR_df3 = MAR_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
MAR_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota          Provinsi
# 0            BOGOR        JAWA BARAT
# 1            BOGOR        JAWA BARAT
# 2        TANGERANG            BANTEN
# 3        TANGERANG            BANTEN
# 4         WONOSOBO       JAWA TENGAH
# ..             ...               ...
# 296  LUBUK LINGGAU  SUMATERA SELATAN
# 297       KARAWANG        JAWA BARAT
# 298      PONTIANAK  KALIMANTAN BARAT
# 299      PONTIANAK  KALIMANTAN BARAT
# 300      PONTIANAK  KALIMANTAN BARAT
#
# [301 rows x 2 columns]

# %% [markdown]
# ## APRIL 2020

# %% [markdown]
# ###Load Dataset

# %%
APR_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M.APRIL")
APR_df3
# Out:
#      Tgl Order                      Pemesan    Nama Penerima      Alamat   \
# 0   2020-03-23            Bukalapak Juragan          masrita  Kutai Barat
# 1   2020-03-23                    Tokopedia    Sri damayanti     Denpasar
# 2   2020-03-23             Bukalapak Gudang          I Wayan       Bekasi
# 3   2020-03-23             Bukalapak Gudang  Bahrun Borahima       Cimahi
# 4   2020-03-23                       Lazada  Sofiyah Kaltsum      Bandung
# ..         ...                          ...              ...          ...
# 137        NaT              Total Pemasukan         12627750          NaN
# 138        NaT              Total Eksemplar              138          NaN
# 139        NaT              Total Transaksi              107          NaN
# 140        NaT  Transaksi Retail (WA & WEB)               46          NaN
# 141        NaT       Transaksi Market place               59          NaN
#
#                                            judul buku           Pengarang  \
# ...

# %%
APR_df3 = APR_df3.iloc[:-7 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
APR_df3['Alamat ']=APR_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
APR_df3['Alamat '] = APR_df3['Alamat '].str.upper()
alamat_df = APR_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      KUTAI BARAT
# 1         DENPASAR
# 2           BEKASI
# 3           CIMAHI
# 4          BANDUNG
#           ...
# 130           BALI
# 131         BEKASI
# 132         BEKASI
# 133     YOGYAKARTA
# 134          BLORA
# Name: Alamat , Length: 135, dtype: object

# %%
def kab(alamat):
  kabupaten=''
  alamat_list = alamat.to_list()
  ls_kab = list()
  for i in range(len(alamat_list)):
    for j in list_kab:
      if (str(j) == str(alamat_list[i])):
        #print(j)
        #print(i)
        kabupaten = j
        break
      else:
        # jika tidak ada dalam list, maka ambil kolom kabupaten/kota
        kabupaten = 'UNDEFINED'
    ls_kab.append(kabupaten)
  
  #print(ls_kab)
  return ls_kab

# %%
ls = list()
ls = kab(APR_df3['Alamat '])

# %%
APR_df3['Kabupaten/Kota'] = ls
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
APR_df3
# Out:
#      Tgl Order            Pemesan        Nama Penerima      Alamat   \
# 0   2020-03-23  Bukalapak Juragan              masrita  KUTAI BARAT
# 1   2020-03-23          Tokopedia        Sri damayanti     DENPASAR
# 2   2020-03-23   Bukalapak Gudang              I Wayan       BEKASI
# 3   2020-03-23   Bukalapak Gudang      Bahrun Borahima       CIMAHI
# 4   2020-03-23             Lazada      Sofiyah Kaltsum      BANDUNG
# ..         ...                ...                  ...          ...
# 130 2020-04-23                Web          Ni Putu Ayu         BALI
# 131 2020-04-23             Lazada         Cinthya Inri       BEKASI
# 132 2020-04-23             Lazada         Cinthya Inri       BEKASI
# 133 2020-04-23                 WA  Dirlantas Polda DIY   YOGYAKARTA
# 134 2020-04-23                Web              Sariman        BLORA
#
#                                            judul buku   \
# 0    Pendekatan Penelitian Kuantitatif: Quantitativ...
# ...

# %% [markdown]
# ###Menambakan Kolom Provinsi

# %%
APR_df3 = APR_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
APR_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota          Provinsi
# 0      KUTAI BARAT  KALIMANTAN TIMUR
# 1         DENPASAR              BALI
# 2           BEKASI        JAWA BARAT
# 3           BEKASI        JAWA BARAT
# 4           CIMAHI        JAWA BARAT
# ..             ...               ...
# 170         BEKASI        JAWA BARAT
# 171         BEKASI        JAWA BARAT
# 172         BEKASI        JAWA BARAT
# 173     YOGYAKARTA     DI YOGYAKARTA
# 174          BLORA       JAWA TENGAH
#
# [175 rows x 2 columns]

# %% [markdown]
# ## MEI 2020

# %% [markdown]
# ###Load Dataset

# %%
MEI_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M. MEI")
MEI_df3
# Out:
#      Tgl Order           Pemesan    Nama Penerima            Alamat   \
# 0   2020-04-24            Lazada        Ida Mayda      Jakarta Pusat
# 1   2020-04-24               WA       YF Gunarsih          Surakarta
# 2   2020-04-24               WA       YF Gunarsih          Surakarta
# 3   2020-04-27         Tokopedia          Eprisca  Tangerang Selatan
# 4   2020-04-27  Bukalapak Gudang         Andi Yan             Brebes
# ..         ...               ...              ...                ...
# 105 2020-05-20            Shopee       Alvi divia           Karawang
# 106 2020-05-20                WA  Ngurah Wiryawan             Mengwi
# 107 2020-05-20            Shopee           Emilia   Sumatera selatan
# 108 2020-05-20            Shopee     Aulia safira         Yogyakarta
# 109        NaT               NaN              NaN                NaN
#
#                                            judul buku   \
# 0                           Pengantar Hukum Indonesia
# ...

# %%
MEI_df3 = MEI_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
MEI_df3['Alamat ']=MEI_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
MEI_df3['Alamat '] = MEI_df3['Alamat '].str.upper()
alamat_df = MEI_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0          JAKARTA PUSAT
# 1              SURAKARTA
# 2              SURAKARTA
# 3      TANGERANG SELATAN
# 4                 BREBES
#              ...
# 104               SLEMAN
# 105             KARAWANG
# 106               MENGWI
# 107     SUMATERA SELATAN
# 108           YOGYAKARTA
# Name: Alamat , Length: 109, dtype: object

# %%
def kab(alamat):
  kabupaten=''
  alamat_list = alamat.to_list()
  ls_kab = list()
  for i in range(len(alamat_list)):
    for j in list_kab:
      if (str(j) == str(alamat_list[i])):
        #print(j)
        #print(i)
        kabupaten = j
        break
      else:
        # jika tidak ada dalam list, maka ambil kolom kabupaten/kota
        kabupaten = 'UNDEFINED'
    ls_kab.append(kabupaten)
  
  #print(ls_kab)
  return ls_kab

# %%
ls = list()
ls = kab(MEI_df3['Alamat '])

# %%
MEI_df3['Kabupaten/Kota'] = ls
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
MEI_df3
# Out:
#      Tgl Order           Pemesan    Nama Penerima            Alamat   \
# 0   2020-04-24            Lazada        Ida Mayda      JAKARTA PUSAT
# 1   2020-04-24               WA       YF Gunarsih          SURAKARTA
# 2   2020-04-24               WA       YF Gunarsih          SURAKARTA
# 3   2020-04-27         Tokopedia          Eprisca  TANGERANG SELATAN
# 4   2020-04-27  Bukalapak Gudang         Andi Yan             BREBES
# ..         ...               ...              ...                ...
# 104 2020-05-20                WA              Iis             SLEMAN
# 105 2020-05-20            Shopee       Alvi divia           KARAWANG
# 106 2020-05-20                WA  Ngurah Wiryawan             MENGWI
# 107 2020-05-20            Shopee           Emilia   SUMATERA SELATAN
# 108 2020-05-20            Shopee     Aulia safira         YOGYAKARTA
#
#                                            judul buku   \
# 0                           Pengantar Hukum Indonesia
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
MEI_df3 = MEI_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
MEI_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#         Kabupaten/Kota       Provinsi
# 0        JAKARTA PUSAT    DKI JAKARTA
# 1            SURAKARTA    JAWA TENGAH
# 2            SURAKARTA    JAWA TENGAH
# 3    TANGERANG SELATAN         BANTEN
# 4               BREBES    JAWA TENGAH
# ..                 ...            ...
# 115             SLEMAN  DI YOGYAKARTA
# 116           KARAWANG     JAWA BARAT
# 117          UNDEFINED      UNDEFINED
# 118          UNDEFINED      UNDEFINED
# 119         YOGYAKARTA  DI YOGYAKARTA
#
# [120 rows x 2 columns]

# %% [markdown]
# ## JUNI 2020

# %% [markdown]
# ###Load Dataset

# %%
JUN_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M. JUNI")
JUN_df3
# Out:
#      Tgl Order            Pemesan    Nama Penerima     Alamat   \
# 0   2020-05-22             Lazada           Elma P   Tangerang
# 1   2020-05-22            Website          Fitri W       Depok
# 2   2020-05-22            Website        Ayu fitri      Klaten
# 3   2020-05-22                 WA  Muhammad Taufan    Makassar
# 4   2020-05-26          Tokopedia          Sutikno   Tangerang
# ..         ...                ...              ...         ...
# 138 2020-06-23  Bukalapak Juragan          Saptono     Ciledug
# 139 2020-06-23                 WA         Kak Afif  Yogyakarta
# 140 2020-06-24   Bukalapak Gudang            Unang     Bandung
# 141 2020-06-24                Web         Astrilia       Bogor
# 142        NaT                NaN              NaN         NaN
#
#                                            judul buku   \
# 0                    Keselamatan dan Kesehatan Kerja -
# 1          Perencanaan Pembangunan Partisipatif Desa -
# ...

# %%
JUN_df3 = JUN_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
JUN_df3['Alamat ']=JUN_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JUN_df3['Alamat '] = JUN_df3['Alamat '].str.upper()
alamat_df = JUN_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0       TANGERANG
# 1           DEPOK
# 2          KLATEN
# 3        MAKASSAR
# 4       TANGERANG
#           ...
# 137       BANDUNG
# 138       CILEDUG
# 139    YOGYAKARTA
# 140       BANDUNG
# 141         BOGOR
# Name: Alamat , Length: 142, dtype: object

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
JUN_df3['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JUN_df3
# Out:
#      Tgl Order            Pemesan    Nama Penerima     Alamat   \
# 0   2020-05-22             Lazada           Elma P   TANGERANG
# 1   2020-05-22            Website          Fitri W       DEPOK
# 2   2020-05-22            Website        Ayu fitri      KLATEN
# 3   2020-05-22                 WA  Muhammad Taufan    MAKASSAR
# 4   2020-05-26          Tokopedia          Sutikno   TANGERANG
# ..         ...                ...              ...         ...
# 137 2020-06-23          Tokopedia              Ria     BANDUNG
# 138 2020-06-23  Bukalapak Juragan          Saptono     CILEDUG
# 139 2020-06-23                 WA         Kak Afif  YOGYAKARTA
# 140 2020-06-24   Bukalapak Gudang            Unang     BANDUNG
# 141 2020-06-24                Web         Astrilia       BOGOR
#
#                                            judul buku   \
# 0                    Keselamatan dan Kesehatan Kerja -
# 1          Perencanaan Pembangunan Partisipatif Desa -
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
JUN_df3 = JUN_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
JUN_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota          Provinsi
# 0        TANGERANG            BANTEN
# 1        TANGERANG            BANTEN
# 2            DEPOK        JAWA BARAT
# 3           KLATEN       JAWA TENGAH
# 4         MAKASSAR  SULAWESI SELATAN
# ..             ...               ...
# 166     YOGYAKARTA     DI YOGYAKARTA
# 167        BANDUNG        JAWA BARAT
# 168        BANDUNG        JAWA BARAT
# 169          BOGOR        JAWA BARAT
# 170          BOGOR        JAWA BARAT
#
# [171 rows x 2 columns]

# %% [markdown]
# ## JULI 2020

# %% [markdown]
# ###Load Dataset

# %%
JUL_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M.JULI")
JUL_df3
# Out:
#      Tgl Order    Pemesan             Nama Penerima  \
# 0   2020-06-25  Tokopedia                 Suwastono
# 1   2020-06-25        Web  Mochamad Yusuf Kurniawan
# 2   2020-06-25        Web  Mochamad Yusuf Kurniawan
# 3   2020-06-25        Web  Mochamad Yusuf Kurniawan
# 4   2020-06-25        Web  Mochamad Yusuf Kurniawan
# ..         ...        ...                       ...
# 263 2020-07-23        Web                Diemas Nur
# 264 2020-07-23        Web                Diemas Nur
# 265 2020-07-23        Web                Diemas Nur
# 266 2020-07-23        Web               Siti Raudah
# 267        NaT        NaN                       NaN
#
#                                                Alamat   \
# 0    Jl. Mahesa No. 20 Rt 06 RW 04 Depan Utara Pasa...
# 1    Jl. Merpati No. 18 Genteng\nGenteng\nKabupaten...
# 2    Jl. Merpati No. 18 Genteng\nGenteng\nKabupaten...
# 3    Jl. Merpati No. 18 Genteng\nGenteng\nKabupaten...
# 4    Jl. Merpati No. 18 Genteng\nGenteng\nKabupaten...
# ...

# %%
JUL_df3 = JUL_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
JUL_df3['Alamat ']=JUL_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JUL_df3['Alamat '] = JUL_df3['Alamat '].str.upper()
alamat_df = JUL_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      JL. MAHESA NO. 20 RT 06 RW 04 DEPAN UTARA PASA...
# 1      JL. MERPATI NO. 18 GENTENG\nGENTENG\nKABUPATEN...
# 2      JL. MERPATI NO. 18 GENTENG\nGENTENG\nKABUPATEN...
# 3      JL. MERPATI NO. 18 GENTENG\nGENTENG\nKABUPATEN...
# 4      JL. MERPATI NO. 18 GENTENG\nGENTENG\nKABUPATEN...
#                              ...
# 262    DSN PULE DS BAKALANPULE RT 4 RW 3 GG. KEBUNREJ...
# 263    JL MUSI 1 BLOK C NOMER 1 KEL. BUGANGAN\nSEMARA...
# 264    JL MUSI 1 BLOK C NOMER 1 KEL. BUGANGAN\nSEMARA...
# 265    JL MUSI 1 BLOK C NOMER 1 KEL. BUGANGAN\nSEMARA...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
JUL_df3['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
JUL_df3
# Out:
#      Tgl Order    Pemesan             Nama Penerima  \
# 0   2020-06-25  Tokopedia                 Suwastono
# 1   2020-06-25        Web  Mochamad Yusuf Kurniawan
# 2   2020-06-25        Web  Mochamad Yusuf Kurniawan
# 3   2020-06-25        Web  Mochamad Yusuf Kurniawan
# 4   2020-06-25        Web  Mochamad Yusuf Kurniawan
# ..         ...        ...                       ...
# 262 2020-07-23         WA                   M. Arif
# 263 2020-07-23        Web                Diemas Nur
# 264 2020-07-23        Web                Diemas Nur
# 265 2020-07-23        Web                Diemas Nur
# 266 2020-07-23        Web               Siti Raudah
#
#                                                Alamat   \
# 0    JL. MAHESA NO. 20 RT 06 RW 04 DEPAN UTARA PASA...
# 1    JL. MERPATI NO. 18 GENTENG\nGENTENG\nKABUPATEN...
# 2    JL. MERPATI NO. 18 GENTENG\nGENTENG\nKABUPATEN...
# 3    JL. MERPATI NO. 18 GENTENG\nGENTENG\nKABUPATEN...
# 4    JL. MERPATI NO. 18 GENTENG\nGENTENG\nKABUPATEN...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
JUL_df3 = JUL_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
JUL_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#          Kabupaten/Kota           Provinsi
# 0                MALANG         JAWA TIMUR
# 1                MALANG         JAWA TIMUR
# 2            BANYUWANGI         JAWA TIMUR
# 3            BANYUWANGI         JAWA TIMUR
# 4            BANYUWANGI         JAWA TIMUR
# ..                  ...                ...
# 300            SEMARANG        JAWA TENGAH
# 301            SEMARANG        JAWA TENGAH
# 302            SEMARANG        JAWA TENGAH
# 303            SEMARANG        JAWA TENGAH
# 304  KOTAWARINGIN BARAT  KALIMANTAN TENGAH
#
# [305 rows x 2 columns]

# %% [markdown]
# ##AGUSTUS 2020

# %% [markdown]
# ###Load Dataset

# %%
AGUS_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M. AGUSTUS")
AGUS_df3
# Out:
#      Tgl Order    Pemesan            Nama Penerima  \
# 0   2020-07-24         WA                Darmawati
# 1   2020-07-24         WA                Darmawati
# 2   2020-07-24        Web  Nita Sari Narulita Dewi
# 3   2020-07-24        Web              I Ketut Oka
# 4   2020-07-24  Tokopedia               Josesimoes
# ..         ...        ...                      ...
# 211 2020-08-24         WA               Basith Abi
# 212 2020-08-24         WA                     Toni
# 213 2020-08-24         WA                     Toni
# 214 2020-08-24         WA                   Bilqis
# 215        NaT        NaN                      NaN
#
#                                                Alamat   \
# 0    Jl. P. Antasari Gg. 5 Blok A1 No. 2 Kel Teluk ...
# 1    Jl. P. Antasari Gg. 5 Blok A1 No. 2 Kel Teluk ...
# 2    JL.LEUWI ANYAR NO 31 BABAKAN KALANG SARI RT 00...
# 3    Jalan Sidakarya No. 157 Br. Sekar Kangin, Denp...
# 4    Penjahit Cv. Viktori jalan Janti Gowok Caturtu...
# ...

# %%
AGUS_df3 = AGUS_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
AGUS_df3['Alamat ']=AGUS_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
AGUS_df3['Alamat '] = AGUS_df3['Alamat '].str.upper()
alamat_df = AGUS_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      JL. P. ANTASARI GG. 5 BLOK A1 NO. 2 KEL TELUK ...
# 1      JL. P. ANTASARI GG. 5 BLOK A1 NO. 2 KEL TELUK ...
# 2      JL.LEUWI ANYAR NO 31 BABAKAN KALANG SARI RT 00...
# 3      JALAN SIDAKARYA NO. 157 BR. SEKAR KANGIN, DENP...
# 4      PENJAHIT CV. VIKTORI JALAN JANTI GOWOK CATURTU...
#                              ...
# 210    JALAN RAYA KRAMAT RT 05 RW 01 DESA KRAMAT KEC....
# 211    JALAN RAYA KRAMAT RT 05 RW 01 DESA KRAMAT KEC....
# 212    JL MERDEKA NO 32, PULO BRAYAN KOTA, 20239\n  K...
# 213    JL MERDEKA NO 32, PULO BRAYAN KOTA, 20239\n  K...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
AGUS_df3['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
AGUS_df3
# Out:
#      Tgl Order    Pemesan            Nama Penerima  \
# 0   2020-07-24         WA                Darmawati
# 1   2020-07-24         WA                Darmawati
# 2   2020-07-24        Web  Nita Sari Narulita Dewi
# 3   2020-07-24        Web              I Ketut Oka
# 4   2020-07-24  Tokopedia               Josesimoes
# ..         ...        ...                      ...
# 210 2020-08-24         WA               Basith Abi
# 211 2020-08-24         WA               Basith Abi
# 212 2020-08-24         WA                     Toni
# 213 2020-08-24         WA                     Toni
# 214 2020-08-24         WA                   Bilqis
#
#                                                Alamat   \
# 0    JL. P. ANTASARI GG. 5 BLOK A1 NO. 2 KEL TELUK ...
# 1    JL. P. ANTASARI GG. 5 BLOK A1 NO. 2 KEL TELUK ...
# 2    JL.LEUWI ANYAR NO 31 BABAKAN KALANG SARI RT 00...
# 3    JALAN SIDAKARYA NO. 157 BR. SEKAR KANGIN, DENP...
# 4    PENJAHIT CV. VIKTORI JALAN JANTI GOWOK CATURTU...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
AGUS_df3 = AGUS_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
AGUS_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota          Provinsi
# 0        SAMARINDA  KALIMANTAN TIMUR
# 1        SAMARINDA  KALIMANTAN TIMUR
# 2      TASIKMALAYA        JAWA BARAT
# 3      TASIKMALAYA        JAWA BARAT
# 4         DENPASAR              BALI
# ..             ...               ...
# 247          TEGAL       JAWA TENGAH
# 248          TEGAL       JAWA TENGAH
# 249          MEDAN    SUMATERA UTARA
# 250          MEDAN    SUMATERA UTARA
# 251      PALEMBANG  SUMATERA SELATAN
#
# [252 rows x 2 columns]

# %% [markdown]
# ## SEPTEMBER 2020

# %% [markdown]
# ###Load Dataset

# %%
SEPT_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M. SEPTEMBER")
SEPT_df3
# Out:
#      Tgl Order            Pemesan   Nama Penerima  \
# 0   2020-08-25             Shopee    Dian Natalia
# 1   2020-08-25          Tokopedia            Bala
# 2   2020-08-25          Tokopedia            Bala
# 3   2020-08-25   Bukalapak Gudang          Dadang
# 4   2020-08-25  Bukalapak Juragan        Ibu Bima
# ..         ...                ...             ...
# 334 2020-09-24   Bukalapak Gudang    Dedi Effendi
# 335 2020-09-24                 wa     arif rahman
# 336 2020-09-24             Shopee  Siti Nur Anisa
# 337 2020-09-24                 wa    Bedi Susanto
# 338        NaT                NaN             NaN
#
#                                                Alamat   \
# 0    PT Tosan mash Jl. Kudus Purwodadi KM 1 Tanjung...
# 1    Bidan Nurdina Jl. Dahlia RT 9 RW 2 Desa Milang...
# 2    Bidan Nurdina Jl. Dahlia RT 9 RW 2 Desa Milang...
# 3    Kontrakan Purbaya 2 No. 16/15 Jl. Ondo Suhandi...
# 4    Jalan Condet Baru No. 142 RT 003 RW 003 Kel Ba...
# ...

# %%
SEPT_df3 = SEPT_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
SEPT_df3['Alamat ']=SEPT_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
SEPT_df3['Alamat '] = SEPT_df3['Alamat '].str.upper()
alamat_df = SEPT_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      PT TOSAN MASH JL. KUDUS PURWODADI KM 1 TANJUNG...
# 1      BIDAN NURDINA JL. DAHLIA RT 9 RW 2 DESA MILANG...
# 2      BIDAN NURDINA JL. DAHLIA RT 9 RW 2 DESA MILANG...
# 3      KONTRAKAN PURBAYA 2 NO. 16/15 JL. ONDO SUHANDI...
# 4      JALAN CONDET BARU NO. 142 RT 003 RW 003 KEL BA...
#                              ...
# 333    DSN.NGASINAN RT.03 RW.04 KELURAHAN REJOMULYO K...
# 334    JL. RM KAHFI I RT 10/06, NO. 118, GG. BULIND, ...
# 335                                           YOGYAKARTA
# 336    JL. SELAM VI NO.10 MANDALA BY PASS. KELURAHAN ...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
SEPT_df3['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
SEPT_df3
# Out:
#      Tgl Order            Pemesan   Nama Penerima  \
# 0   2020-08-25             Shopee    Dian Natalia
# 1   2020-08-25          Tokopedia            Bala
# 2   2020-08-25          Tokopedia            Bala
# 3   2020-08-25   Bukalapak Gudang          Dadang
# 4   2020-08-25  Bukalapak Juragan        Ibu Bima
# ..         ...                ...             ...
# 333 2020-09-24                 WA           Wahyu
# 334 2020-09-24   Bukalapak Gudang    Dedi Effendi
# 335 2020-09-24                 wa     arif rahman
# 336 2020-09-24             Shopee  Siti Nur Anisa
# 337 2020-09-24                 wa    Bedi Susanto
#
#                                                Alamat   \
# 0    PT TOSAN MASH JL. KUDUS PURWODADI KM 1 TANJUNG...
# 1    BIDAN NURDINA JL. DAHLIA RT 9 RW 2 DESA MILANG...
# 2    BIDAN NURDINA JL. DAHLIA RT 9 RW 2 DESA MILANG...
# 3    KONTRAKAN PURBAYA 2 NO. 16/15 JL. ONDO SUHANDI...
# 4    JALAN CONDET BARU NO. 142 RT 003 RW 003 KEL BA...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
SEPT_df3 = SEPT_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
SEPT_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#       Kabupaten/Kota        Provinsi
# 0              KUDUS     JAWA TENGAH
# 1            MAGETAN      JAWA TIMUR
# 2            MAGETAN      JAWA TIMUR
# 3             BEKASI      JAWA BARAT
# 4             BEKASI      JAWA BARAT
# ..               ...             ...
# 401           KEDIRI      JAWA TIMUR
# 402  JAKARTA SELATAN     DKI JAKARTA
# 403       YOGYAKARTA   DI YOGYAKARTA
# 404            MEDAN  SUMATERA UTARA
# 405        UNDEFINED       UNDEFINED
#
# [406 rows x 2 columns]

# %% [markdown]
# ## OKTOBER 2020

# %% [markdown]
# ###Load Dataset

# %%
OKT_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M.OKTOBER")
OKT_df3
# Out:
#      Tgl Order    Pemesan      Nama Penerima  \
# 0   2020-09-25     Shopee           Silalaku
# 1   2020-09-25     Shopee     Indah Rezekika
# 2   2020-09-25     Shopee            Luh Sri
# 3   2020-09-25     Shopee        Leti Astuti
# 4   2020-09-25     Shopee     Jummiramadanii
# ..         ...        ...                ...
# 234 2020-10-21  tokopedia    Nengah Yudiawan
# 235 2020-10-21  bukalapak    Dr Sodikin M Si
# 236 2020-10-21     shopee  Innesya Maghfirah
# 237 2020-10-21     shopee  Innesya Maghfirah
# 238        NaT        NaN                NaN
#
#                                                Alamat   \
# 0    Jalan Bratang Gede III E No. 20, KOTA SURABAYA...
# 1    jalan dr payungan no 139 tanobato, KOTA PADANG...
# 2    Jl. Legian no 57, Kuta, Badung, Bali, KAB. BAD...
# 3    Ds. Langut Rt.02 Rw.01, KAB. INDRAMAYU, LOHBEN...
# 4    Jln. Bypass RT 01/RW 01 Kel. Payolansek (Disam...
# ..                                                 ...
# ...

# %%
OKT_df3 = OKT_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/Kota dari Alamat

# %%
OKT_df3['Alamat ']=OKT_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
OKT_df3['Alamat '] = OKT_df3['Alamat '].str.upper()
alamat_df = OKT_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      JALAN BRATANG GEDE III E NO. 20, KOTA SURABAYA...
# 1      JALAN DR PAYUNGAN NO 139 TANOBATO, KOTA PADANG...
# 2      JL. LEGIAN NO 57, KUTA, BADUNG, BALI, KAB. BAD...
# 3      DS. LANGUT RT.02 RW.01, KAB. INDRAMAYU, LOHBEN...
# 4      JLN. BYPASS RT 01/RW 01 KEL. PAYOLANSEK (DISAM...
#                              ...
# 233    SMK PEMKAB PONOROGO, JL MARGO MULYO NO 2\n  KE...
# 234    JL.NUSANTARA BR DINAS GEBAGAN DESA KAYUBIHI KE...
# 235    METRO PARUNG PANJANG BLOK H1 NO. 22 DS. CIBUNA...
# 236    JLN. PELITA 1 (GANGNYA SEBERANG PELITA FUTSAL,...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
OKT_df3['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
OKT_df3
# Out:
#      Tgl Order    Pemesan      Nama Penerima  \
# 0   2020-09-25     Shopee           Silalaku
# 1   2020-09-25     Shopee     Indah Rezekika
# 2   2020-09-25     Shopee            Luh Sri
# 3   2020-09-25     Shopee        Leti Astuti
# 4   2020-09-25     Shopee     Jummiramadanii
# ..         ...        ...                ...
# 233 2020-10-20         wa      Syaiful bahri
# 234 2020-10-21  tokopedia    Nengah Yudiawan
# 235 2020-10-21  bukalapak    Dr Sodikin M Si
# 236 2020-10-21     shopee  Innesya Maghfirah
# 237 2020-10-21     shopee  Innesya Maghfirah
#
#                                                Alamat   \
# 0    JALAN BRATANG GEDE III E NO. 20, KOTA SURABAYA...
# 1    JALAN DR PAYUNGAN NO 139 TANOBATO, KOTA PADANG...
# 2    JL. LEGIAN NO 57, KUTA, BADUNG, BALI, KAB. BAD...
# 3    DS. LANGUT RT.02 RW.01, KAB. INDRAMAYU, LOHBEN...
# 4    JLN. BYPASS RT 01/RW 01 KEL. PAYOLANSEK (DISAM...
# ..                                                 ...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
OKT_df3 = OKT_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
OKT_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#       Kabupaten/Kota        Provinsi
# 0           SURABAYA      JAWA TIMUR
# 1    PADANGSIDIMPUAN  SUMATERA UTARA
# 2             BADUNG            BALI
# 3          INDRAMAYU      JAWA BARAT
# 4         PAYAKUMBUH  SUMATERA BARAT
# ..               ...             ...
# 283           BANGLI            BALI
# 284            BOGOR      JAWA BARAT
# 285            BOGOR      JAWA BARAT
# 286            MEDAN  SUMATERA UTARA
# 287            MEDAN  SUMATERA UTARA
#
# [288 rows x 2 columns]

# %% [markdown]
# ## NOVEMBER 2020

# %% [markdown]
# ###Load Dataset

# %%
NOV_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M.NOVEMBER")
NOV_df3
# Out:
#      Tgl Order    Pemesan    Nama Penerima  \
# 0   2020-10-22         wa             dewi
# 1   2020-10-22     shopee          Sr. Lia
# 2   2020-10-22         wa    alistia irang
# 3   2020-10-22         wa    alistia irang
# 4   2020-10-22         wa       muslimin z
# ..         ...        ...              ...
# 286 2020-11-23         wa  Agus Tri Widodo
# 287 2020-11-23  bukalapak    Badirun Basir
# 288 2020-11-23  bukalapak    Badirun Basir
# 289 2020-11-23         wa           arizka
# 290        NaT        NaN              NaN
#
#                                                Alamat   \
# 0    perum griya benowo indah blok d no 4 surabaya\...
# 1    Biara kesusteran SSpS komunitas Roh Suci, KAB....
# 2    MAN 1 kongbeng NO. 01 jalan pembagunan miau ba...
# 3    MAN 1 kongbeng NO. 01 jalan pembagunan miau ba...
# 4     jl. Poros bontang samarinda km. 8, yayasan al...
# ..                                                 ...
# ...

# %%
NOV_df3 = NOV_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/kota dari Alamat

# %%
NOV_df3['Alamat ']=NOV_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
NOV_df3['Alamat '] = NOV_df3['Alamat '].str.upper()
alamat_df = NOV_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      PERUM GRIYA BENOWO INDAH BLOK D NO 4 SURABAYA\...
# 1      BIARA KESUSTERAN SSPS KOMUNITAS ROH SUCI, KAB....
# 2      MAN 1 KONGBENG NO. 01 JALAN PEMBAGUNAN MIAU BA...
# 3      MAN 1 KONGBENG NO. 01 JALAN PEMBAGUNAN MIAU BA...
# 4       JL. POROS BONTANG SAMARINDA KM. 8, YAYASAN AL...
#                              ...
# 285    JALAN DR. LEIMENA NO. 42, KEL/KEC.  TELLO BARU...
# 286     JOGOBONDO RT 1/ RW 21\n  KECAMATAN: MOJOLABAN...
# 287    BAGIAN KEUANGAN GEDUNG REKTORAT LANTAI III KAM...
# 288    BAGIAN KEUANGAN GEDUNG REKTORAT LANTAI III KAM...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
NOV_df3['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
NOV_df3
# Out:
#      Tgl Order    Pemesan    Nama Penerima  \
# 0   2020-10-22         wa             dewi
# 1   2020-10-22     shopee          Sr. Lia
# 2   2020-10-22         wa    alistia irang
# 3   2020-10-22         wa    alistia irang
# 4   2020-10-22         wa       muslimin z
# ..         ...        ...              ...
# 285 2020-11-23         wa      Hendry Riko
# 286 2020-11-23         wa  Agus Tri Widodo
# 287 2020-11-23  bukalapak    Badirun Basir
# 288 2020-11-23  bukalapak    Badirun Basir
# 289 2020-11-23         wa           arizka
#
#                                                Alamat   \
# 0    PERUM GRIYA BENOWO INDAH BLOK D NO 4 SURABAYA\...
# 1    BIARA KESUSTERAN SSPS KOMUNITAS ROH SUCI, KAB....
# 2    MAN 1 KONGBENG NO. 01 JALAN PEMBAGUNAN MIAU BA...
# 3    MAN 1 KONGBENG NO. 01 JALAN PEMBAGUNAN MIAU BA...
# 4     JL. POROS BONTANG SAMARINDA KM. 8, YAYASAN AL...
# ..                                                 ...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
NOV_df3 = NOV_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
NOV_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#     Kabupaten/Kota          Provinsi
# 0         SURABAYA        JAWA TIMUR
# 1           SLEMAN     DI YOGYAKARTA
# 2      KUTAI TIMUR  KALIMANTAN TIMUR
# 3      KUTAI TIMUR  KALIMANTAN TIMUR
# 4      KUTAI TIMUR  KALIMANTAN TIMUR
# ..             ...               ...
# 333       MAKASSAR  SULAWESI SELATAN
# 334      SUKOHARJO       JAWA TENGAH
# 335       MAKASSAR  SULAWESI SELATAN
# 336       MAKASSAR  SULAWESI SELATAN
# 337     YOGYAKARTA     DI YOGYAKARTA
#
# [338 rows x 2 columns]

# %% [markdown]
# ## DESEMBER 2020

# %% [markdown]
# ###Load Dataset

# %%
DES_df3 = pd.read_excel("https://github.com/dickyilhami/Analysis-Book-Sales/blob/main/Dataset/data-order-online-2020-ed.xlsx?raw=true", sheet_name = "M.DESEMBER")
DES_df3
# Out:
#      Tgl Order Pemesan                    Nama Penerima  \
# 0   2020-11-24  shopee               Siti Rahmah Hayati
# 1   2020-11-24  shopee               Siti Rahmah Hayati
# 2   2020-11-24      wa                 Noer Jihad Saleh
# 3   2020-11-25      wa  Muhammad Fikri Al Aziz (Ubhara)
# 4   2020-11-25  shopee                  Nindi sholikhah
# ..         ...     ...                              ...
# 255 2020-12-22     web           Hesti Dyah Puspitasari
# 256 2020-12-22     web           Hesti Dyah Puspitasari
# 257 2020-12-22  shopee    Shopee International Platform
# 258 2020-12-22     web              Saktiwansyah Efendi
# 259        NaT     NaN                              NaN
#
#                                                Alamat   \
# 0    BTN Sandubaya Asri No. B5 Selong, KAB. LOMBOK ...
# 1    BTN Sandubaya Asri No. B5 Selong, KAB. LOMBOK ...
# 2    perum dosen Unhas Blok EB/18 Tamalanrea, Makassar
# 3    rumah no Ar 22, jln Deplu raya, pondok pinang ...
# ...

# %%
DES_df3 = DES_df3.iloc[:-1 , :]

# %% [markdown]
# ###Memisahkan Kabupaten/kota dari Alamat

# %%
DES_df3['Alamat ']=DES_df3['Alamat '].apply(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
DES_df3['Alamat '] = DES_df3['Alamat '].str.upper()
alamat_df = DES_df3['Alamat ']
alamat_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      BTN SANDUBAYA ASRI NO. B5 SELONG, KAB. LOMBOK ...
# 1      BTN SANDUBAYA ASRI NO. B5 SELONG, KAB. LOMBOK ...
# 2      PERUM DOSEN UNHAS BLOK EB/18 TAMALANREA, MAKASSAR
# 3      RUMAH NO AR 22, JLN DEPLU RAYA, PONDOK PINANG ...
# 4      PERUMAHAN CIPTA PERMATA BLOK H 1 NO 13, KOTA B...
#                              ...
# 254    SEKOLAH TINGGI ILMU KESEHATAN KEPANJEN\nJL. TR...
# 255    SEKOLAH TINGGI ILMU KESEHATAN KEPANJEN\nJL. TR...
# 256    SEKOLAH TINGGI ILMU KESEHATAN KEPANJEN\nJL. TR...
# 257    JL. KAPUK KAMAL MUARA NO.88, RT.004 RW.001, TE...
# ...

# %%
def Kab(alamat):
  kabupaten = ""
  if re.search('KABUPATEN/KOTA',alamat) :
    tmp = re.search('KABUPATEN/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB/KOTA',alamat):
    tmp = re.search('KAB/KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KAB',alamat):
    tmp = re.search('KAB',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KOTA',alamat):
    tmp = re.search('KOTA',alamat)
    data_to_find = alamat[tmp.end()::]
  elif re.search('KABUPATEN',alamat):
    tmp = re.search('KABUPATEN',alamat)
    data_to_find = alamat[tmp.end()::]
  else:
    data_to_find = alamat

  for kab in list_kab:
    if kab in data_to_find:
      kabupaten = kab
      break

  if (kabupaten == ''):
    kabupaten = 'UNDEFINED'
  
  return kabupaten

# %%
data_alamat = [Kab(alamat) for alamat in alamat_df.to_list()]

# %%
DES_df3['Kabupaten/Kota'] = data_alamat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
DES_df3
# Out:
#      Tgl Order Pemesan                    Nama Penerima  \
# 0   2020-11-24  shopee               Siti Rahmah Hayati
# 1   2020-11-24  shopee               Siti Rahmah Hayati
# 2   2020-11-24      wa                 Noer Jihad Saleh
# 3   2020-11-25      wa  Muhammad Fikri Al Aziz (Ubhara)
# 4   2020-11-25  shopee                  Nindi sholikhah
# ..         ...     ...                              ...
# 254 2020-12-22     web           Hesti Dyah Puspitasari
# 255 2020-12-22     web           Hesti Dyah Puspitasari
# 256 2020-12-22     web           Hesti Dyah Puspitasari
# 257 2020-12-22  shopee    Shopee International Platform
# 258 2020-12-22     web              Saktiwansyah Efendi
#
#                                                Alamat   \
# 0    BTN SANDUBAYA ASRI NO. B5 SELONG, KAB. LOMBOK ...
# 1    BTN SANDUBAYA ASRI NO. B5 SELONG, KAB. LOMBOK ...
# 2    PERUM DOSEN UNHAS BLOK EB/18 TAMALANREA, MAKASSAR
# 3    RUMAH NO AR 22, JLN DEPLU RAYA, PONDOK PINANG ...
# ...

# %% [markdown]
# ###Menambahkan Kolom Provinsi

# %%
DES_df3 = DES_df3.merge(prov_df, on='Kabupaten/Kota', how='left')

# %%
DES_df3.loc[:,['Kabupaten/Kota', 'Provinsi']]
# Out:
#       Kabupaten/Kota             Provinsi
# 0       LOMBOK TIMUR  NUSA TENGGARA BARAT
# 1       LOMBOK TIMUR  NUSA TENGGARA BARAT
# 2           MAKASSAR     SULAWESI SELATAN
# 3    JAKARTA SELATAN          DKI JAKARTA
# 4              BATAM       KEPULAUAN RIAU
# ..               ...                  ...
# 322           MALANG           JAWA TIMUR
# 323           MALANG           JAWA TIMUR
# 324           MALANG           JAWA TIMUR
# 325    JAKARTA BARAT          DKI JAKARTA
# 326         KARAWANG           JAWA BARAT
#
# [327 rows x 2 columns]

# %% [markdown]
# ##Menggabungkan Seluruh Sheet menjadi satu DataFrame dan Check DataFrame-nya

# %%
df3_concat = pd.concat([JAN_df3,FEB_df3,MAR_df3,APR_df3,MEI_df3,JUN_df3,JUL_df3,AGUS_df3,SEPT_df3,OKT_df3,NOV_df3,DES_df3])

df3_concat
# Out:
#       No  Tgl Order    Pemesan                  Nama Penerima  \
# 0    1.0 2019-12-30     Sherly                            NaN
# 1    2.0 2019-12-30      Nelis                            NaN
# 2    2.0 2019-12-30      Nelis                            NaN
# 3    3.0 2019-12-30      Richo                            NaN
# 4    4.0 2020-01-03  Anggi Dwi                            NaN
# ..   ...        ...        ...                            ...
# 322  NaN 2020-12-22        web         Hesti Dyah Puspitasari
# 323  NaN 2020-12-22        web         Hesti Dyah Puspitasari
# 324  NaN 2020-12-22        web         Hesti Dyah Puspitasari
# 325  NaN 2020-12-22     shopee  Shopee International Platform
# 326  NaN 2020-12-22        web            Saktiwansyah Efendi
#
#                                                Alamat   \
# 0                                        LUBUK LINGGAU
# 1                                              BANDUNG
# ...

# %%
df3_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3020 entries, 0 to 326
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   No                             638 non-null    float64
#  1   Tgl Order                      3020 non-null   datetime64[ns]
#  2   Pemesan                        3020 non-null   object
#  3   Nama Penerima                  2554 non-null   object
#  4   Alamat                         3020 non-null   object
#  5   judul buku                     3020 non-null   object
#  6   Pengarang                      3015 non-null   object
#  7   jumlah pesanan                 3020 non-null   float64
#  8   harga satuan                   3016 non-null   float64
#  9   jumlah penjualan               3020 non-null   float64
#  10  discount                       510 non-null    float64
#  11  harga setelah diskon           3020 non-null   float64
# ...

# %% [markdown]
# ##Memperbaiki format dari fitur-fitur yang ada pada Dataset 3

# %%
df3_concat.columns
# Out:
# Index(['No', 'Tgl Order', 'Pemesan', 'Nama Penerima', 'Alamat ', 'judul buku ',
#        'Pengarang', 'jumlah pesanan ', 'harga satuan ', 'jumlah penjualan',
#        'discount', 'harga setelah diskon', 'ongkos kirim', 'Service fee',
#        'total', 'order via', 'nomor transaksi (invoice dll)', 'KET',
#        'tgl kirim ', 'resi ', 'Total per judul', 'Royalti', 'Total Real',
#        'Diskon', 'Unnamed: 24', 'Unnamed: 25', 'No.1', 'Market Place',
#        'Tanggal', 'Pukul', 'Nilai Saldo', 'Kabupaten/Kota', 'Provinsi',
#        'No HP', 'Unnamed: 26', 'Unnamed: 23'],
#       dtype='object')

# %%
df3_concat.rename(columns={'judul buku ': 'Judul Buku','jumlah pesanan ':'Jumlah Pesanan','total':'Total Pembayaran'}, inplace=True)

# %%
df3_concat['Judul Buku'] = df3_concat['Judul Buku'].str.title()
df3_concat['Judul Buku']
# Out:
# 0      Peningkatan Kinerja Sumber Daya Manusia Melalu...
# 1      Modul Edukasi Gizi Pencegahan Dan Penanggulang...
# 2      Modul Edukasi Gizi Pencegahan Dan Penanggulang...
# 3      Konsep Dan Desain Sistem Rangka Momen Khusus (...
# 4              Ekstrakurikuler Pendidikan Agama Islam -
#                              ...
# 322    Manajemen Informasi Kesehatan: Pengelolaan Dok...
# 323                      Pemasaran Produk Jasa Kesehatan
# 324                      Pemasaran Produk Jasa Kesehatan
# 325                                   English In Nursing
# 326        Pengantar Sanitasi Industri Pengolahan Pangan
# Name: Judul Buku, Length: 3020, dtype: object

# %%
df3_concat['Jumlah Pesanan'] = df3_concat['Jumlah Pesanan'].astype(int)

# %%
df3_concat['Total Pembayaran'] = df3_concat['Total Pembayaran'].astype(float)

# %% [markdown]
# ##Memisahkan Month dan Year dari Tgl Order pada Dataset 3

# %%
df3_concat['Month'] = pd.DatetimeIndex(df3_concat['Tgl Order']).month

# %%
df3_concat['Year'] = pd.DatetimeIndex(df3_concat['Tgl Order']).year

# %%
df3_concat
# Out:
#       No  Tgl Order    Pemesan                  Nama Penerima  \
# 0    1.0 2019-12-30     Sherly                            NaN
# 1    2.0 2019-12-30      Nelis                            NaN
# 2    2.0 2019-12-30      Nelis                            NaN
# 3    3.0 2019-12-30      Richo                            NaN
# 4    4.0 2020-01-03  Anggi Dwi                            NaN
# ..   ...        ...        ...                            ...
# 322  NaN 2020-12-22        web         Hesti Dyah Puspitasari
# 323  NaN 2020-12-22        web         Hesti Dyah Puspitasari
# 324  NaN 2020-12-22        web         Hesti Dyah Puspitasari
# 325  NaN 2020-12-22     shopee  Shopee International Platform
# 326  NaN 2020-12-22        web            Saktiwansyah Efendi
#
#                                                Alamat   \
# 0                                        LUBUK LINGGAU
# 1                                              BANDUNG
# ...

# %% [markdown]
# ##Memisahkan Fitur-Fitur yang diperlukan untuk Analisa kedalam sebuah DataFrame Baru pada Dataset 3

# %%
df31 = df3_concat.loc[:,['Year', 'Month', 'Kabupaten/Kota', 'Provinsi','Judul Buku','Jumlah Pesanan','Total Pembayaran']]
df31
# Out:
#      Year  Month Kabupaten/Kota          Provinsi  \
# 0    2019     12  LUBUK LINGGAU  SUMATERA SELATAN
# 1    2019     12        BANDUNG        JAWA BARAT
# 2    2019     12        BANDUNG        JAWA BARAT
# 3    2019     12       SIDOARJO        JAWA TIMUR
# 4    2020      1        CIANJUR        JAWA BARAT
# ..    ...    ...            ...               ...
# 322  2020     12         MALANG        JAWA TIMUR
# 323  2020     12         MALANG        JAWA TIMUR
# 324  2020     12         MALANG        JAWA TIMUR
# 325  2020     12  JAKARTA BARAT       DKI JAKARTA
# 326  2020     12       KARAWANG        JAWA BARAT
#
#                                             Judul Buku  Jumlah Pesanan  \
# 0    Peningkatan Kinerja Sumber Daya Manusia Melalu...               1
# 1    Modul Edukasi Gizi Pencegahan Dan Penanggulang...               1
# 2    Modul Edukasi Gizi Pencegahan Dan Penanggulang...               1
# 3    Konsep Dan Desain Sistem Rangka Momen Khusus (...               1
# ...

# %%
df31.dtypes
# Out:
# Year                  int64
# Month                 int64
# Kabupaten/Kota       object
# Provinsi             object
# Judul Buku           object
# Jumlah Pesanan        int64
# Total Pembayaran    float64
# dtype: object

# %% [markdown]
# #GABUNGAN DATAFRAME

# %%
df = pd.concat([df11, df21, df31])

df
# Out:
#      Year  Month Kabupaten/Kota          Provinsi  \
# 0    2020     10      SUKOHARJO       JAWA TENGAH
# 1    2020     10  JAKARTA TIMUR       DKI JAKARTA
# 2    2020     12       SIDOARJO        JAWA TIMUR
# 3    2020     12      SAMARINDA  KALIMANTAN TIMUR
# 4    2020     12          LAHAT  SUMATERA SELATAN
# ..    ...    ...            ...               ...
# 322  2020     12         MALANG        JAWA TIMUR
# 323  2020     12         MALANG        JAWA TIMUR
# 324  2020     12         MALANG        JAWA TIMUR
# 325  2020     12  JAKARTA BARAT       DKI JAKARTA
# 326  2020     12       KARAWANG        JAWA BARAT
#
#                                             Judul Buku  Jumlah Pesanan  \
# 0                  Konstruksi Bangunan - Buku Original               1
# 1    Kiat Sukses Meraih Hibah Penelitian Pengembang...               1
# 2    Promo Buku Pembelajaran Inkuiri Di Masa Pandem...               1
# 3    Semiotika Dokumenter:Membongkar Dekonstruksi M...               1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21590 entries, 0 to 326
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              21590 non-null  int64
#  1   Month             21590 non-null  int64
#  2   Kabupaten/Kota    21590 non-null  object
#  3   Provinsi          21542 non-null  object
#  4   Judul Buku        21590 non-null  object
#  5   Jumlah Pesanan    21590 non-null  int64
#  6   Total Pembayaran  21577 non-null  float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.3+ MB

# %%
dfx = df.sort_values(by=['Year','Month'], ascending=[True,True])
dfx
# Out:
#      Year  Month Kabupaten/Kota          Provinsi  \
# 33   2019      1        CIREBON        JAWA BARAT
# 34   2019      1        CIREBON        JAWA BARAT
# 0    2019     12  LUBUK LINGGAU  SUMATERA SELATAN
# 1    2019     12        BANDUNG        JAWA BARAT
# 2    2019     12        BANDUNG        JAWA BARAT
# ..    ...    ...            ...               ...
# 500  2021     12      PEKANBARU              RIAU
# 501  2021     12       MAKASSAR  SULAWESI SELATAN
# 502  2021     12        KEBUMEN       JAWA TENGAH
# 503  2021     12        KEBUMEN       JAWA TENGAH
# 504  2021     12   TOBA SAMOSIR    SUMATERA UTARA
#
#                                             Judul Buku  Jumlah Pesanan  \
# 33   Model Pembagian Jasa Pelayanan Di Rumah Sakit ...               1
# 34   Model Pembagian Jasa Pelayanan Di Rumah Sakit ...               1
# 0    Peningkatan Kinerja Sumber Daya Manusia Melalu...               1
# 1    Modul Edukasi Gizi Pencegahan Dan Penanggulang...               1
# ...

# %%
dfx.head()
# Out:
#     Year  Month Kabupaten/Kota          Provinsi  \
# 33  2019      1        CIREBON        JAWA BARAT
# 34  2019      1        CIREBON        JAWA BARAT
# 0   2019     12  LUBUK LINGGAU  SUMATERA SELATAN
# 1   2019     12        BANDUNG        JAWA BARAT
# 2   2019     12        BANDUNG        JAWA BARAT
#
#                                            Judul Buku  Jumlah Pesanan  \
# 33  Model Pembagian Jasa Pelayanan Di Rumah Sakit ...               1
# 34  Model Pembagian Jasa Pelayanan Di Rumah Sakit ...               1
# 0   Peningkatan Kinerja Sumber Daya Manusia Melalu...               1
# 1   Modul Edukasi Gizi Pencegahan Dan Penanggulang...               1
# 2   Modul Edukasi Gizi Pencegahan Dan Penanggulang...               1
#
#     Total Pembayaran
# 33           99900.0
# 34           99900.0
# 0            59295.0
# 1            57230.0
# 2            57230.0

# %%
from google.colab import files
dfx.to_excel('deepublish.xlsx', encoding='utf-8', index=False) 
files.download('deepublish.xlsx')

# %% [markdown]
# #MENAMPILKAN JUDUL BUKU YANG PALING LARIS DI SETIAP KABUPATEN/KOTA

# %% [markdown]
# ##Judul Buku yang Paling Laris di Setiap Kabupaten

# %%
Kab1_df1 = df.groupby(['Provinsi','Kabupaten/Kota','Judul Buku']).agg({'Jumlah Pesanan':'sum'}).reset_index()
Kab1_df1 = Kab1_df1.rename(columns={'Jumlah Pesanan': 'Total_Penjualan'})
Kab1_df1.sort_values(by=['Provinsi','Kabupaten/Kota','Total_Penjualan'], ascending=[True,True,False])
# Out:
#         Provinsi Kabupaten/Kota  \
# 0           ACEH     ACEH BARAT
# 2           ACEH     ACEH BARAT
# 1           ACEH     ACEH BARAT
# 3           ACEH     ACEH BARAT
# 4           ACEH     ACEH BARAT
# ...          ...            ...
# 15993  UNDEFINED      UNDEFINED
# 15994  UNDEFINED      UNDEFINED
# 15995  UNDEFINED      UNDEFINED
# 15996  UNDEFINED      UNDEFINED
# 15997  UNDEFINED      UNDEFINED
#
#                                               Judul Buku  Total_Penjualan
# 0      Buku "Matematika Diskrit Dan Penerapannya Dala...                2
# 2            Buku Arsitektur Komputer - Akhlis Munazilin                2
# 1                  Buku Ajar Pengantar Aplikasi Komputer                1
# 3      Buku Pemusnahan Arsip Di Lingkungan Pemerintah...                1
# 4      Buku Perancangan Tata Letak Pabrik - Buku Orig...                1
# ...                                                  ...              ...
# ...

# %% [markdown]
# ##Judul Buku yang Paling Laris di Kabupaten/Kota setiap Bulannya

# %%
Kab_df1 = df.groupby(['Provinsi','Kabupaten/Kota','Year','Month','Judul Buku']).agg({'Jumlah Pesanan':'sum'}).reset_index()
Kab_df1 = Kab_df1.rename(columns={'Jumlah Pesanan': 'Total_Penjualan'})
Kab_df1.sort_values(by=['Provinsi','Kabupaten/Kota','Year','Month','Total_Penjualan'], ascending=[True,True,True,True,False])
# Out:
#         Provinsi Kabupaten/Kota  Year  Month  \
# 0           ACEH     ACEH BARAT  2020      3
# 1           ACEH     ACEH BARAT  2020      9
# 2           ACEH     ACEH BARAT  2020      9
# 3           ACEH     ACEH BARAT  2021      2
# 4           ACEH     ACEH BARAT  2021      2
# ...          ...            ...   ...    ...
# 16877  UNDEFINED      UNDEFINED  2021     11
# 16878  UNDEFINED      UNDEFINED  2021     11
# 16880  UNDEFINED      UNDEFINED  2021     12
# 16879  UNDEFINED      UNDEFINED  2021     12
# 16881  UNDEFINED      UNDEFINED  2021     12
#
#                                               Judul Buku  Total_Penjualan
# 0      Keselamatan Dan Kesehatan Kerja Kelautan: (Kaj...                1
# 1                  Buku Ajar Pengantar Aplikasi Komputer                1
# 2                            Teknologi Pengolahan Limbah                1
# 3      Buku "Matematika Diskrit Dan Penerapannya Dala...                2
# ...

# %% [markdown]
# #MENAMPILKAN TOTAL PENJUALAN BUKU SETIAP KABUPATEN/KOTA

# %% [markdown]
# ####Total Penjualan Buku Setiap Kabupaten/Kota

# %%
Kab1_df = df.groupby(['Provinsi','Kabupaten/Kota']).agg({'Jumlah Pesanan':'sum'}).reset_index()
Kab1_df = Kab1_df.rename(columns={'Jumlah Pesanan': 'Total_Penjualan'})
Kab1_df.sort_values(by=['Provinsi','Kabupaten/Kota','Total_Penjualan',], ascending=[True,True,False])
# Out:
#            Provinsi   Kabupaten/Kota  Total_Penjualan
# 0              ACEH       ACEH BARAT                9
# 1              ACEH  ACEH BARAT DAYA                1
# 2              ACEH       ACEH BESAR                6
# 3              ACEH     ACEH TAMIANG                3
# 4              ACEH      ACEH TENGAH                2
# ..              ...              ...              ...
# 399  SUMATERA UTARA  TAPANULI TENGAH                6
# 400  SUMATERA UTARA   TAPANULI UTARA                6
# 401  SUMATERA UTARA    TEBING TINGGI                3
# 402  SUMATERA UTARA     TOBA SAMOSIR               14
# 403       UNDEFINED        UNDEFINED              490
#
# [404 rows x 3 columns]

# %% [markdown]
# ####Total Penjualan Buku di Kabupaten/Kota Setiap Bulannya

# %%
Kab_df = df.groupby(['Provinsi','Kabupaten/Kota','Year','Month']).agg({'Jumlah Pesanan':'sum'}).reset_index()
Kab_df = Kab_df.rename(columns={'Jumlah Pesanan': 'Total_Penjualan'})
Kab_df.sort_values(by=['Provinsi','Kabupaten/Kota','Year','Month','Total_Penjualan'], ascending=[True,True,True,True,False])
# Out:
#        Provinsi Kabupaten/Kota  Year  Month  Total_Penjualan
# 0          ACEH     ACEH BARAT  2020      3                1
# 1          ACEH     ACEH BARAT  2020      9                2
# 2          ACEH     ACEH BARAT  2021      2                4
# 3          ACEH     ACEH BARAT  2021      6                1
# 4          ACEH     ACEH BARAT  2021      9                1
# ...         ...            ...   ...    ...              ...
# 3392  UNDEFINED      UNDEFINED  2021      6                3
# 3393  UNDEFINED      UNDEFINED  2021      8               12
# 3394  UNDEFINED      UNDEFINED  2021      9                4
# 3395  UNDEFINED      UNDEFINED  2021     11               14
# 3396  UNDEFINED      UNDEFINED  2021     12                7
#
# [3397 rows x 5 columns]

# %% [markdown]
# #MENAMPILKAN TREN PENJUALAN BUKU

# %%
Tren_df = df.groupby(['Kabupaten/Kota','Judul Buku','Month','Year']).agg({'Jumlah Pesanan':'sum'}).reset_index()
Tren_df = Tren_df.rename(columns={'Jumlah Pesanan': 'Total_Penjualan'})
Tren_df.sort_values(by=['Kabupaten/Kota','Judul Buku','Year','Month'], ascending=[True,True,True,True])
# Out:
#       Kabupaten/Kota                                         Judul Buku  \
# 0         ACEH BARAT  Buku "Matematika Diskrit Dan Penerapannya Dala...
# 1         ACEH BARAT              Buku Ajar Pengantar Aplikasi Komputer
# 2         ACEH BARAT        Buku Arsitektur Komputer - Akhlis Munazilin
# 3         ACEH BARAT  Buku Pemusnahan Arsip Di Lingkungan Pemerintah...
# 4         ACEH BARAT  Buku Perancangan Tata Letak Pabrik - Buku Orig...
# ...              ...                                                ...
# 16828     YOGYAKARTA            Viktimologi Dan Sistem Peradilan Pidana
# 16829     YOGYAKARTA            Viktimologi Dan Sistem Peradilan Pidana
# 16831     YOGYAKARTA  Yurisdiksi Asas Oportunitas Dalam Sistem Perad...
# 16832     YOGYAKARTA  Yurisdiksi Asas Oportunitas Dalam Sistem Perad...
# 16830     YOGYAKARTA  Yurisdiksi Asas Oportunitas Dalam Sistem Perad...
#
#        Month  Year  Total_Penjualan
# 0          2  2021                2
# ...

# %% [markdown]
# #TOTAL PENJUALAN BUKU PER KABUPATEN

# %%
Kab1_df = df.groupby(['Provinsi','Kabupaten/Kota']).agg({'Total Pembayaran':'sum'}).reset_index()
Kab1_df = Kab1_df.rename(columns={'Total Pembayaran': 'Total Pembayaran'})
Kab1_df.sort_values(by=['Provinsi','Kabupaten/Kota','Total Pembayaran'], ascending=[True,True,False])
# Out:
#            Provinsi   Kabupaten/Kota  Total Pembayaran
# 0              ACEH       ACEH BARAT         1121769.0
# 1              ACEH  ACEH BARAT DAYA          104375.0
# 2              ACEH       ACEH BESAR          786811.0
# 3              ACEH     ACEH TAMIANG          400000.0
# 4              ACEH      ACEH TENGAH          266501.0
# ..              ...              ...               ...
# 399  SUMATERA UTARA  TAPANULI TENGAH          691182.0
# 400  SUMATERA UTARA   TAPANULI UTARA          692918.0
# 401  SUMATERA UTARA    TEBING TINGGI          406780.0
# 402  SUMATERA UTARA     TOBA SAMOSIR         1202159.0
# 403       UNDEFINED        UNDEFINED        45926960.0
#
# [404 rows x 3 columns]

# %%
x = df['Provinsi'].unique()

# %%
x
# Out:
# array(['JAWA TENGAH', 'DKI JAKARTA', 'JAWA TIMUR', 'KALIMANTAN TIMUR',
#        'SUMATERA SELATAN', 'RIAU', 'JAWA BARAT', 'DI YOGYAKARTA',
#        'NUSA TENGGARA BARAT', 'SULAWESI TENGAH', 'LAMPUNG',
#        'SULAWESI SELATAN', 'SUMATERA UTARA', 'GORONTALO',
#        'KALIMANTAN UTARA', 'JAMBI', 'KALIMANTAN TENGAH',
#        'KALIMANTAN BARAT', 'BANTEN', 'PAPUA', 'SULAWESI TENGGARA',
#        'KALIMANTAN SELATAN', 'SULAWESI UTARA', 'SUMATERA BARAT',
#        'KEPULAUAN RIAU', 'BALI', 'BENGKULU', 'KEPULAUAN BANGKA BELITUNG',
#        'SULAWESI BARAT', 'PAPUA BARAT', nan, 'MALUKU UTARA', 'ACEH',
#        'NUSA TENGGARA TIMUR', 'MALUKU', 'UNDEFINED'], dtype=object)

# %%
len(x)
# Out:
# 36
